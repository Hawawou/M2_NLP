# %% [markdown]
# **LAB1 - NeSy Recommendation System**

# %% [markdown]
# Movie Recommendation System
# Recommend movies to users based on explicit preferences.
#
# We will go through probabilistic uncertainty, vague knowledge, commonsense reasoning, and similarity-based inference. More precisely:
#
# * Classical Prolog= Structured rules for explicit knowledge (e.g., “Alice likes Sci-Fi → Recommend Sci-Fi movies”)
# * Probabilistic Prolog: Uncertain preferences (e.g., “Alice probably likes Sci-Fi with 80% confidence”)
# * Possibilistic Prolog Vague or imprecise knowledge (e.g., “If Alice likes Sci-Fi, she might like Cyberpunk”)
# * Commonsense Reasoning	Interpolation & analogy-based reasoning (e.g., “Alice likes Action and Sci-Fi → Infer she might like Cyberpunk”)
# * Similarity-Based Reasoning	Vector embeddings for contextual similarity (e.g., “Inception is similar to Interstellar → Recommend Interstellar”)

# %% [markdown]
# Let's do concept spaces

# %% [markdown]
# Let's start with the following step
#
# * Step 1: Define the Logical Rules (Prolog)
# * Step 2: Introduce Probabilistic Reasoning (Probabilistic Prolog)
# * Step 3: Handle Vague Knowledge (Possibilistic Prolog)
# * Step 4: Implement Commonsense Reasoning
# * Step 5: Implement Similarity-Based Reasoning Using Vector Embeddings
# * Step 6:
#     - Integrate real-world datasets (IMDB, MovieLens)
#     - Enhance user personalization (e.g., feedback loops)
#     - Reason with Embeddings

# %%
from pyswip import Prolog

# %% [markdown]
# ## Logical rules

# %%
prolog = Prolog()


prolog.assertz("likes(alice, sci_fi)")
prolog.assertz("genre(alice, cyberpunk)")
prolog.assertz("genre(alice, action)")


result = list(prolog.query("genre(alice, X)"))

# Print result
print(result)
# Out:
# [{'X': 'cyberpunk'}, {'X': 'action'}]

# %%
prolog = Prolog()


prolog.assertz("likes(alice, sci_fi)")
prolog.assertz("likes(alice, action)")


prolog.assertz("movie(interstellar, sci_fi)")
prolog.assertz("movie(inception, sci_fi)")
prolog.assertz("movie(matrix, sci_fi)")
prolog.assertz("movie(john_wick, action)")
prolog.assertz("movie(mad_max, action)")
prolog.assertz("movie(blade_runner, cyberpunk)")


prolog.assertz("similar(inception, interstellar)")
prolog.assertz("similar(matrix, blade_runner)")


prolog.assertz("recommend(User, Movie) :- likes(User, Genre), movie(Movie, Genre)")


prolog.assertz("recommend_similar(User, Movie) :- likes(User, Genre), movie(LikedMovie, Genre), similar(LikedMovie, Movie)")

# Query for movie recommendations for Alice
result = list(prolog.query("recommend(alice, Movie)"))
print("Genre-Based Recommendations:", result)

# # Query for similarity-based recommendations for Alice
# similar_results = list(prolog.query("recommend_similar(alice, Movie)"))
# print("Similarity-Based Recommendations:", similar_results)
# Out:
# Genre-Based Recommendations: [{'Movie': 'interstellar'}, {'Movie': 'inception'}, {'Movie': 'matrix'}, {'Movie': 'interstellar'}, {'Movie': 'inception'}, {'Movie': 'matrix'}, {'Movie': 'interstellar'}, {'Movie': 'inception'}, {'Movie': 'matrix'}, {'Movie': 'interstellar'}, {'Movie': 'inception'}, {'Movie': 'matrix'}, {'Movie': 'john_wick'}, {'Movie': 'mad_max'}, {'Movie': 'john_wick'}, {'Movie': 'mad_max'}, {'Movie': 'interstellar'}, {'Movie': 'inception'}, {'Movie': 'matrix'}, {'Movie': 'interstellar'}, {'Movie': 'inception'}, {'Movie': 'matrix'}, {'Movie': 'john_wick'}, {'Movie': 'mad_max'}, {'Movie': 'john_wick'}, {'Movie': 'mad_max'}, {'Movie': 'interstellar'}, {'Movie': 'inception'}, {'Movie': 'matrix'}, {'Movie': 'interstellar'}, {'Movie': 'inception'}, {'Movie': 'matrix'}, {'Movie': 'interstellar'}, {'Movie': 'inception'}, {'Movie': 'matrix'}, {'Movie': 'interstellar'}, {'Movie': 'inception'}, {'Movie': 'matrix'}, {'Movie': 'john_wick'}, {'Movie': 'mad_max'}, {'Movie': 'john_wick'}, {'Movie': 'mad_max'}, {'Movie': 'interstellar'}, {'Movie': 'inception'}, {'Movie': 'matrix'}, {'Movie': 'interstellar'}, {'Movie': 'inception'}, {'Movie': 'matrix'}, {'Movie': 'john_wick'}, {'Movie': 'mad_max'}, {'Movie': 'john_wick'}, {'Movie': 'mad_max'}]

# %% [markdown]
# ## Probabilistic reasoning

# %%
from problog.program import PrologString
from problog import get_evaluatable


problog_code = """
% Facts with probabilities
0.8::likes(alice, sci_fi).
0.6::likes(alice, cyberpunk).
0.7::likes(alice, action).

% Movie genres
movie(interstellar, sci_fi).
movie(inception, sci_fi).
movie(matrix, sci_fi).
movie(john_wick, action).
movie(mad_max, action).
movie(blade_runner, cyberpunk).

% Probabilistic similarity between movies
0.9::similar(inception, interstellar).
0.7::similar(matrix, blade_runner).

% Probabilistic recommendation rule
0.9::recommend(User, Movie) :- likes(User, Genre), movie(Movie, Genre).
0.8::recommend(User, Movie) :- likes(User, Genre), movie(Movie, Genre), similar(Movie, SimilarMovie).
"""

# Load ProbLog program
problog_model = PrologString(problog_code)

# Query probabilistic recommendations for Alice
result = get_evaluatable().create_from(problog_model).evaluate()
print(result)

# Print recommendation probabilities
for key, value in result.items():
    if "recommend(alice" in str(key):  # Filter only recommendation results
        print(f"{key}: {value:.2f}")
# Out:
# {}

# %%
import pandas as pd
import torch

data = pd.read_csv("imdb_top_1000.csv")
data.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %% [markdown]
# From embeddings, use bag of words to find most frequent words, SVM to cluster and find interpretable direction

# %%
# Implement Similarity-Based Reasoning Using Vector Embeddings
from sentence_transformers import SentenceTransformer

# Load pre-trained Sentence Transformer model
model = SentenceTransformer("paraphrase-MiniLM-L6-v2")

# Encode movie titles into vector embeddings
movie_embeddings = model.encode(data["Overview"], convert_to_tensor=True)
# Out:
# [0.99999994 0.99999994 0.9999999  0.99999994 1.         1.
#  1.0000001  0.99999994 1.         1.         1.         1.
#  1.0000001  1.         0.99999994 1.0000001  1.         1.
#  1.0000001  1.         0.9999999  1.         1.         1.
#  0.9999999  1.0000001  0.9999998  1.         1.         1.0000001
#  1.         1.         0.99999994 1.         1.0000002  1.
#  1.0000001  0.99999994 0.9999999  1.0000001  1.         0.99999994
#  0.99999994 1.         1.0000001  1.0000001  0.9999999  1.
#  1.0000001  0.99999994 1.0000001  0.99999994 0.9999999  1.
#  1.         1.         1.         0.99999994 0.99999976 0.99999994
#  1.         0.99999994 1.0000001  1.         1.         1.
#  0.9999999  1.         1.         0.99999994 0.9999999  1.
#  1.         1.         0.9999999  1.0000002  1.         1.
#  1.         1.         0.99999994 0.99999994 0.99999994 1.0000001
#  0.9999999  0.9999999  1.         1.         1.         0.9999999
#  1.0000001  1.0000001  1.         1.         1.         1.0000001
#  0.9999998  0.99999994 1.0000001  1.0000001  0.99999994 1.
#  1.0000001  0.99999994 1.0000001  0.99999994 1.0000001  0.9999999
#  1.         1.         0.9999999  1.         0.9999999  1.
#  1.         1.         0.9999998  1.         1.         1.
#  1.0000001  1.0000001  1.         1.0000001  0.99999994 0.99999994
#  0.99999994 1.         1.         1.0000001  0.9999999  0.9999999
#  1.0000001  1.         1.0000002  0.99999994 1.         0.99999994
#  0.99999994 1.         0.99999994 1.         0.99999994 1.0000001
#  1.         1.0000001  1.         1.         1.         1.
#  1.         1.0000001  0.9999999  1.         0.9999999  1.0000001
#  0.99999976 1.0000001  1.         1.         1.         1.
#  1.         1.         0.9999999  1.         1.0000001  0.99999994
#  1.         0.99999994 1.         1.0000001  1.         0.99999994
#  1.         1.0000001  0.9999999  0.99999994 0.9999999  0.99999994
#  1.         1.         1.         1.         0.9999999  0.99999994
#  1.0000001  1.         1.0000001  1.0000001  1.         1.
#  0.9999999  1.0000001  0.99999994 1.         1.0000001  1.
#  1.         1.         0.99999994 1.         1.         1.
#  1.         1.         1.         1.         1.0000001  1.
#  0.99999994 1.         1.         0.99999994 1.0000001  0.99999994
#  1.0000001  0.9999999  1.         0.99999976 1.         1.0000001
#  1.         0.9999999  0.9999999  1.         0.99999994 0.99999994
#  1.         1.         0.9999998  1.         1.         1.
#  0.99999994 0.99999994 1.         1.         1.0000001  1.
#  1.         1.         1.0000001  0.99999994 0.9999999  0.99999994
#  1.         1.0000001  1.0000001  0.99999994 1.0000001  1.
#  1.         0.99999994 1.         0.9999999  1.         1.
#  1.         0.99999994 0.9999999  1.         1.         0.9999999
#  1.         0.99999994 1.         1.         0.99999994 1.
#  0.99999994 0.9999999  1.         0.99999994 1.         1.
#  0.9999999  1.         0.99999994 1.0000001  1.         0.99999994
#  1.0000001  0.99999994 1.         0.99999994 1.         1.
#  0.9999999  0.9999999  1.         1.         1.         1.
#  1.         0.99999994 1.         1.         1.0000001  1.
#  1.0000001  1.         1.         0.9999999  0.9999999  0.9999999
#  1.         1.0000001  1.0000001  0.9999999  1.         0.9999999
#  1.         0.99999994 1.0000001  0.99999994 1.         1.0000001
#  0.9999999  0.9999998  1.0000001  1.         0.99999994 0.9999999
#  1.0000001  1.         1.         0.9999998  0.9999999  1.
#  1.         1.0000001  1.         0.99999994 1.0000001  1.
#  0.99999994 1.         1.         0.99999994 0.99999994 0.99999994
#  1.         0.99999994 0.99999994 1.         1.         1.
#  0.9999999  0.99999994 1.         1.         1.         0.9999999
#  0.99999994 1.         1.         1.0000001  1.         0.9999999
#  1.0000001  1.0000001  0.99999994 0.99999994 0.9999999  1.
#  1.         1.0000001  1.         0.99999994 1.         1.
#  1.         1.0000001  0.9999999  1.         1.0000001  1.
#  1.         0.9999999  1.         1.         0.9999999  0.99999994
#  1.         1.         1.0000001  0.99999976 1.0000001  0.99999994
#  0.9999999  1.0000001  0.9999999  0.9999999  1.         1.0000002
#  0.9999999  1.0000002  1.         1.         1.         1.
#  0.9999999  1.         1.         1.         1.0000001  1.0000001
#  1.0000001  0.9999999  0.99999994 0.9999998  0.99999994 0.9999998
#  1.         0.99999994 1.         1.         1.         1.
#  0.9999999  0.9999998  1.0000001  1.         1.         1.
#  0.9999998  1.         1.         1.         1.         1.
#  1.0000001  1.         1.         1.         1.         1.
#  1.         0.9999999  1.         0.99999994 1.         1.
#  0.9999999  0.99999994 0.9999999  0.99999994 1.         1.
#  0.9999999  0.99999994 1.         1.         1.0000001  1.
#  1.0000001  1.         1.0000001  1.         1.0000001  1.
#  1.0000001  0.99999994 1.0000001  0.9999999  1.0000001  0.9999999
#  0.99999994 0.9999999  1.         1.         1.         1.0000001
#  1.         1.0000002  1.         1.         1.0000002  0.99999994
#  0.9999999  1.         1.0000001  1.         1.         0.9999999
#  1.         1.0000001  1.         1.         0.9999998  0.99999994
#  1.         1.0000001  1.         1.         1.         0.9999999
#  1.         1.0000001  0.9999999  0.9999999  1.         1.0000001
#  1.0000001  1.         1.0000001  1.         1.0000001  0.9999999
#  1.0000001  1.0000001  0.9999999  0.9999999  0.9999999  1.
#  1.0000001  1.0000001  0.9999998  0.99999994 0.9999999  1.
#  1.0000001  1.         0.9999999  1.0000001  0.9999999  1.
#  1.         0.99999994 1.         1.         0.9999999  0.99999994
#  1.         1.0000001  1.         0.9999999  0.99999994 0.9999999
#  1.         0.99999994 0.9999999  0.9999999  1.         1.
#  1.0000001  0.9999999  0.99999994 0.9999999  0.9999998  1.
#  1.0000001  1.         1.         1.         1.         0.99999994
#  0.9999998  1.         1.         1.0000001  1.         1.
#  1.         0.99999994 1.0000001  0.9999999  0.9999999  0.9999999
#  1.         1.         1.0000001  0.9999999  1.0000001  1.
#  0.99999994 0.99999994 1.0000001  0.99999994 1.         0.9999999
#  1.0000001  0.99999994 1.         1.         1.         1.0000001
#  1.0000001  1.0000001  1.0000001  0.9999999  1.         1.
#  0.99999994 1.0000001  1.         0.99999994 1.         1.0000002
#  0.99999994 1.         0.9999998  0.99999994 1.         0.9999999
#  1.0000001  0.99999994 1.         0.99999994 0.99999994 1.
#  1.         1.         1.0000001  0.9999999  0.9999999  0.99999994
#  1.         1.         1.         1.         1.0000001  1.
#  1.0000001  1.0000001  0.9999999  1.         0.99999994 1.
#  1.0000001  0.99999994 1.         1.0000001  0.99999994 1.
#  0.9999999  1.         1.         0.99999994 1.         0.9999999
#  1.         0.99999994 1.         1.         1.         0.9999999
#  1.         1.         1.0000001  1.0000001  1.0000001  0.9999998
#  1.0000001  1.         1.         1.0000002  1.         1.
#  0.9999999  1.         1.0000002  0.9999999  0.9999999  1.
#  1.0000001  1.0000001  0.99999994 1.         1.0000001  1.
#  1.0000001  0.9999998  1.         0.9999998  1.0000001  1.
#  1.0000001  0.99999994 1.0000001  1.         1.         1.0000001
#  1.         1.         1.         1.         1.         1.0000001
#  0.9999999  1.         1.         1.         1.0000001  0.99999994
#  0.9999998  0.9999999  0.99999994 0.99999994 1.         1.0000001
#  1.         0.99999994 0.99999976 0.9999999  1.         1.0000001
#  1.         1.         0.99999994 1.0000001  0.9999999  0.9999998
#  0.9999999  1.         0.9999999  1.         1.0000001  1.0000001
#  0.99999994 1.0000001  0.9999999  1.         1.         1.
#  0.9999999  1.         0.9999999  1.0000001  1.         1.
#  1.         1.         0.9999999  1.         0.99999994 1.
#  1.         1.0000001  1.         1.0000002  1.         1.
#  1.         1.         0.9999999  1.0000001  1.         0.99999994
#  1.0000001  1.0000001  1.         1.0000001  0.99999994 1.
#  1.         0.9999999  1.         1.         1.0000002  1.0000001
#  1.         0.99999994 1.         1.         0.9999999  1.0000001
#  1.0000001  1.         1.0000001  1.0000001  1.0000001  1.
#  0.99999994 0.99999994 1.         0.99999994 1.         1.0000002
#  1.0000001  1.0000001  1.         1.         0.9999999  0.9999999
#  0.99999994 1.0000001  1.         0.9999999  1.         1.
#  1.0000001  0.99999994 0.99999994 1.         1.         1.
#  1.         0.99999994 0.99999976 1.         0.9999999  1.
#  1.0000001  1.         0.99999994 1.         0.9999998  0.9999999
#  1.         0.9999999  0.99999994 0.99999994 1.0000001  1.
#  0.9999999  0.9999999  0.99999994 1.         1.         1.
#  1.0000001  1.         0.99999994 1.0000001  0.9999999  0.9999999
#  0.9999999  1.         1.         1.         1.         1.
#  1.         1.         0.9999999  1.         0.99999994 0.99999994
#  1.         1.0000001  1.0000001  0.99999994 1.         1.
#  0.9999999  1.0000001  1.         1.0000001  1.0000001  0.9999998
#  1.         0.99999994 0.99999994 1.         1.         1.
#  1.         1.         0.9999999  1.         1.0000002  0.9999999
#  1.0000001  1.         1.         0.9999999  1.0000001  1.
#  0.99999994 1.         1.         1.0000002  0.9999999  1.
#  0.9999999  1.0000001  0.9999999  1.         1.         1.
#  1.         0.9999998  1.         0.99999994 0.99999994 0.99999994
#  0.99999994 0.99999994 1.         1.0000001  1.         1.
#  1.         1.         1.0000001  0.99999976 0.9999998  1.
#  0.99999994 1.         0.99999994 0.9999998  0.99999994 0.99999994
#  1.         0.9999999  0.9999999  1.0000001  1.         1.
#  1.0000001  0.9999999  1.0000001  1.         1.         1.0000001
#  0.9999998  1.         0.99999994 1.         1.         1.0000001
#  1.         1.         1.0000001  0.9999999  1.0000001  1.0000002
#  1.         1.         1.         1.0000001  1.0000001  0.99999994
#  1.0000001  1.         1.         1.         0.9999999  1.
#  1.         0.9999999  0.99999994 1.0000001  0.9999999  1.
#  1.         1.0000001  1.         1.         1.         0.99999994
#  0.9999999  0.99999994 1.         0.9999999  1.         1.
#  1.0000002  1.0000002  0.9999999  1.0000001  0.99999994 1.0000001
#  1.         1.0000002  1.0000001  0.9999998  1.         1.
#  1.0000001  1.         1.         0.99999994 1.         1.0000001
#  1.         0.9999999  0.99999994 0.9999999  1.         1.
#  0.99999994 0.9999999  1.         0.9999999  0.99999994 1.
#  1.0000001  0.9999999  0.99999994 0.9999998  1.0000001  0.9999999
#  1.         0.99999994 1.         0.9999999 ]

# %% [markdown]
# We now know how to develop mention encoders, so we can develop one for movies:
# * Take the list of movie names.
# * For each name, find mention sentences in a corpus.
# * Based on these sentences, extract representations using a BERT-family encoder.
# * Average the mention vectors.
# * Done.

# %%
from transformers import BertTokenizer, BertModel
import torch

# %%
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertModel.from_pretrained("bert-base-uncased")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
# ----> 2 model = BertModel.from_pretrained("bert-base-uncased")
#
# File ~/School/.venv/lib64/python3.12/site-packages/transformers/modeling_utils.py:3825, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    3809 try:
#    3810     # Load from URL or cache if already cached
#    3811     cached_file_kwargs = {
#    3812         "cache_dir": cache_dir,
#    3813         "force_download": force_download,
#    (...)
#    3823         "_commit_hash": commit_hash,
#    3824     }
# -> 3825     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#    3827     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#    3828     # result when internet is up, the repo and revision exist, but the file does not.
#    3829     if resolved_archive_file is None and filename == _add_variant(SAFE_WEIGHTS_NAME, variant):
#    3830         # Maybe the checkpoint is sharded, we try to grab the index name in this case.
#
# File ~/School/.venv/lib64/python3.12/site-packages/transformers/utils/hub.py:403, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     400 user_agent = http_user_agent(user_agent)
#     401 try:
#     402     # Load from URL or cache if already cached
# --> 403     resolved_file = hf_hub_download(
#     404         path_or_repo_id,
#     405         filename,
#     406         subfolder=None if len(subfolder) == 0 else subfolder,
#     407         repo_type=repo_type,
#     408         revision=revision,
#     409         cache_dir=cache_dir,
#     410         user_agent=user_agent,
#     411         force_download=force_download,
#     412         proxies=proxies,
#     413         resume_download=resume_download,
#     414         token=token,
#     415         local_files_only=local_files_only,
#     416     )
#     417 except GatedRepoError as e:
#     418     resolved_file = _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#
# File ~/School/.venv/lib64/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/School/.venv/lib64/python3.12/site-packages/huggingface_hub/file_download.py:860, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     840     return _hf_hub_download_to_local_dir(
#     841         # Destination
#     842         local_dir=local_dir,
#    (...)
#     857         local_files_only=local_files_only,
#     858     )
#     859 else:
# --> 860     return _hf_hub_download_to_cache_dir(
#     861         # Destination
#     862         cache_dir=cache_dir,
#     863         # File info
#     864         repo_id=repo_id,
#     865         filename=filename,
#     866         repo_type=repo_type,
#     867         revision=revision,
#     868         # HTTP info
#     869         endpoint=endpoint,
#     870         etag_timeout=etag_timeout,
#     871         headers=hf_headers,
#     872         proxies=proxies,
#     873         token=token,
#     874         # Additional options
#     875         local_files_only=local_files_only,
#     876         force_download=force_download,
#     877     )
#
# File ~/School/.venv/lib64/python3.12/site-packages/huggingface_hub/file_download.py:1009, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1007 Path(lock_path).parent.mkdir(parents=True, exist_ok=True)
#    1008 with WeakFileLock(lock_path):
# -> 1009     _download_to_tmp_and_move(
#    1010         incomplete_path=Path(blob_path + ".incomplete"),
#    1011         destination_path=Path(blob_path),
#    1012         url_to_download=url_to_download,
#    1013         proxies=proxies,
#    1014         headers=headers,
#    1015         expected_size=expected_size,
#    1016         filename=filename,
#    1017         force_download=force_download,
#    1018     )
#    1019     if not os.path.exists(pointer_path):
#    1020         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File ~/School/.venv/lib64/python3.12/site-packages/huggingface_hub/file_download.py:1543, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download)
#    1540         _check_disk_space(expected_size, incomplete_path.parent)
#    1541         _check_disk_space(expected_size, destination_path.parent)
# -> 1543     http_get(
#    1544         url_to_download,
#    1545         f,
#    1546         proxies=proxies,
#    1547         resume_size=resume_size,
#    1548         headers=headers,
#    1549         expected_size=expected_size,
#    1550     )
#    1552 logger.info(f"Download complete. Moving file to {destination_path}")
#    1553 _chmod_and_move(incomplete_path, destination_path)
#
# File ~/School/.venv/lib64/python3.12/site-packages/huggingface_hub/file_download.py:452, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     450 new_resume_size = resume_size
#     451 try:
# --> 452     for chunk in r.iter_content(chunk_size=constants.DOWNLOAD_CHUNK_SIZE):
#     453         if chunk:  # filter out keep-alive new chunks
#     454             progress.update(len(chunk))
#
# File ~/School/.venv/lib64/python3.12/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/School/.venv/lib64/python3.12/site-packages/urllib3/response.py:1060, in HTTPResponse.stream(self, amt, decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1060         data = self.read(amt=amt, decode_content=decode_content)
#    1062         if data:
#    1063             yield data
#
# File ~/School/.venv/lib64/python3.12/site-packages/urllib3/response.py:949, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     946     if len(self._decoded_buffer) >= amt:
#     947         return self._decoded_buffer.get(amt)
# --> 949 data = self._raw_read(amt)
#     951 flush_decoder = amt is None or (amt != 0 and not data)
#     953 if not data and len(self._decoded_buffer) == 0:
#
# File ~/School/.venv/lib64/python3.12/site-packages/urllib3/response.py:873, in HTTPResponse._raw_read(self, amt, read1)
#     870 fp_closed = getattr(self._fp, "closed", False)
#     872 with self._error_catcher():
# --> 873     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     874     if amt is not None and amt != 0 and not data:
#     875         # Platform-specific: Buggy versions of Python.
#     876         # Close the connection when no data is returned
#    (...)
#     881         # not properly close the connection in all cases. There is
#     882         # no harm in redundantly calling close.
#     883         self._fp.close()
#
# File ~/School/.venv/lib64/python3.12/site-packages/urllib3/response.py:856, in HTTPResponse._fp_read(self, amt, read1)
#     853     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     854 else:
#     855     # StringIO doesn't like amt=None
# --> 856     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /usr/lib64/python3.12/http/client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File /usr/lib64/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File /usr/lib64/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib64/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Extract sentences that mention the movie names
movie_names = data['Series_Title'].tolist()
movie_overviews = data['Overview'].tolist()

def extract_mention_sentences(movie_names, movie_overviews):
    mention_sentences = [sentence for sentence in movie_overviews if movie_names.lower() in sentence.lower()]
    return mention_sentences

for i in movie_names:
    mention_sentences = extract_mention_sentences(i, movie_overviews)
    print(f"Movie: {i}")
    print(f"Mentioned Sentences: {mention_sentences}\n")
# Out:
# Movie: The Shawshank Redemption
# Mentioned Sentences: []
#
# Movie: The Godfather
# Mentioned Sentences: []
#
# Movie: The Dark Knight
# Mentioned Sentences: []
#
# Movie: The Godfather: Part II
# Mentioned Sentences: []
#
# Movie: 12 Angry Men
# Mentioned Sentences: []
#
# Movie: The Lord of the Rings: The Return of the King
# Mentioned Sentences: []
#
# Movie: Pulp Fiction
# Mentioned Sentences: []
#
# Movie: Schindler's List
# Mentioned Sentences: []
#
# Movie: Inception
# Mentioned Sentences: []
#
# Movie: Fight Club
# Mentioned Sentences: ['An insomniac office worker and a devil-may-care soapmaker form an underground fight club that evolves into something much, much more.']
#
# Movie: The Lord of the Rings: The Fellowship of the Ring
# Mentioned Sentences: []
#
# Movie: Forrest Gump
# Mentioned Sentences: []
#
# Movie: Il buono, il brutto, il cattivo
# Mentioned Sentences: []
#
# Movie: The Lord of the Rings: The Two Towers
# Mentioned Sentences: []
#
# Movie: The Matrix
# Mentioned Sentences: []
#
# Movie: Goodfellas
# Mentioned Sentences: []
#
# Movie: Star Wars: Episode V - The Empire Strikes Back
# Mentioned Sentences: []
#
# Movie: One Flew Over the Cuckoo's Nest
# Mentioned Sentences: []
#
# Movie: Hamilton
# Mentioned Sentences: ["The real life of one of America's foremost founding fathers and first Secretary of the Treasury, Alexander Hamilton. Captured live on Broadway from the Richard Rodgers Theater with the original Broadway cast."]
#
# Movie: Gisaengchung
# Mentioned Sentences: []
#
# Movie: Soorarai Pottru
# Mentioned Sentences: []
#
# Movie: Interstellar
# Mentioned Sentences: []
#
# Movie: Cidade de Deus
# Mentioned Sentences: []
#
# Movie: Sen to Chihiro no kamikakushi
# Mentioned Sentences: []
#
# Movie: Saving Private Ryan
# Mentioned Sentences: []
#
# Movie: The Green Mile
# Mentioned Sentences: []
#
# Movie: La vita è bella
# Mentioned Sentences: []
#
# Movie: Se7en
# Mentioned Sentences: []
#
# Movie: The Silence of the Lambs
# Mentioned Sentences: []
#
# Movie: Star Wars
# Mentioned Sentences: []
#
# Movie: Seppuku
# Mentioned Sentences: ["When a ronin requesting seppuku at a feudal lord's palace is told of the brutal suicide of another ronin who previously visited, he reveals how their pasts are intertwined - and in doing so challenges the clan's integrity."]
#
# Movie: Shichinin no samurai
# Mentioned Sentences: []
#
# Movie: It's a Wonderful Life
# Mentioned Sentences: []
#
# Movie: Joker
# Mentioned Sentences: ['When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.', 'In Gotham City, mentally troubled comedian Arthur Fleck is disregarded and mistreated by society. He then embarks on a downward spiral of revolution and bloody crime. This path brings him face-to-face with his alter-ego: the Joker.', "Eight years after the Joker's reign of anarchy, Batman, with the help of the enigmatic Catwoman, is forced from his exile to save Gotham City from the brutal guerrilla terrorist Bane."]
#
# Movie: Whiplash
# Mentioned Sentences: []
#
# Movie: The Intouchables
# Mentioned Sentences: []
#
# Movie: The Prestige
# Mentioned Sentences: []
#
# Movie: The Departed
# Mentioned Sentences: []
#
# Movie: The Pianist
# Mentioned Sentences: []
#
# Movie: Gladiator
# Mentioned Sentences: []
#
# Movie: American History X
# Mentioned Sentences: []
#
# Movie: The Usual Suspects
# Mentioned Sentences: []
#
# Movie: Léon
# Mentioned Sentences: ["Mathilda, a 12-year-old girl, is reluctantly taken in by Léon, a professional assassin, after her family is murdered. An unusual relationship forms as she becomes his protégée and learns the assassin's trade."]
#
# Movie: The Lion King
# Mentioned Sentences: []
#
# Movie: Terminator 2: Judgment Day
# Mentioned Sentences: []
#
# Movie: Nuovo Cinema Paradiso
# Mentioned Sentences: []
#
# Movie: Hotaru no haka
# Mentioned Sentences: []
#
# Movie: Back to the Future
# Mentioned Sentences: []
#
# Movie: Once Upon a Time in the West
# Mentioned Sentences: []
#
# Movie: Psycho
# Mentioned Sentences: ['When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.', 'Will Hunting, a janitor at M.I.T., has a gift for mathematics, but needs help from a psychologist to find direction in his life.', 'In a post-apocalyptic wasteland, a woman rebels against a tyrannical ruler in search for her homeland with the aid of a group of female prisoners, a psychotic worshiper, and a drifter named Max.', 'A boy who communicates with spirits seeks the help of a disheartened child psychologist.', 'A psychologist is sent to a station orbiting a distant planet in order to discover what has caused the crew to go insane.', 'A psychopathic criminal with a mother complex makes a daring break from prison and leads his old gang in a chemical plant payroll heist.', 'A secret military project endangers Neo-Tokyo when it turns a biker gang member into a rampaging psychic psychopath who can only be stopped by two teenagers and a group of psychics.', 'A psychopath forces a tennis star to comply with his theory that two strangers can get away with murder.', "A psychological thriller of a grieving mother turned cold-blooded avenger with a twisty master plan to pay back those who were responsible for her daughter's death.", 'Three former parapsychology professors set up shop as a unique ghost removal service.', 'The discovery of a severed human ear found in a field leads a young man on an investigation related to a beautiful, mysterious nightclub singer and a group of psychopathic criminals who have kidnapped her child.', 'When a madman calling himself "the Scorpio Killer" menaces the city, tough-as-nails San Francisco Police Inspector "Dirty" Harry Callahan is assigned to track down and ferret out the crazed psychopath.', 'A wealthy New York City investment banking executive, Patrick Bateman, hides his alternate psychopathic ego from his co-workers and friends as he delves deeper into his violent, hedonistic fantasies.', 'An oddball journalist and his psychopathic lawyer travel to Las Vegas for a series of psychedelic escapades.', 'An ordinary man frustrated with the various flaws he sees in society begins to psychotically and violently lash out against them.']
#
# Movie: Casablanca
# Mentioned Sentences: []
#
# Movie: Modern Times
# Mentioned Sentences: []
#
# Movie: City Lights
# Mentioned Sentences: []
#
# Movie: Capharnaüm
# Mentioned Sentences: []
#
# Movie: Ayla: The Daughter of War
# Mentioned Sentences: []
#
# Movie: Vikram Vedha
# Mentioned Sentences: []
#
# Movie: Kimi no na wa.
# Mentioned Sentences: []
#
# Movie: Dangal
# Mentioned Sentences: []
#
# Movie: Spider-Man: Into the Spider-Verse
# Mentioned Sentences: []
#
# Movie: Avengers: Endgame
# Mentioned Sentences: []
#
# Movie: Avengers: Infinity War
# Mentioned Sentences: ["After the devastating events of Avengers: Infinity War (2018), the universe is in ruins. With the help of remaining allies, the Avengers assemble once more in order to reverse Thanos' actions and restore balance to the universe."]
#
# Movie: Coco
# Mentioned Sentences: []
#
# Movie: Django Unchained
# Mentioned Sentences: []
#
# Movie: The Dark Knight Rises
# Mentioned Sentences: []
#
# Movie: 3 Idiots
# Mentioned Sentences: []
#
# Movie: Taare Zameen Par
# Mentioned Sentences: []
#
# Movie: WALL·E
# Mentioned Sentences: []
#
# Movie: The Lives of Others
# Mentioned Sentences: ['A high-school girl named Makoto acquires the power to travel back in time, and decides to use it for her own personal benefits. Little does she know that she is affecting the lives of others just as much as she is her own.']
#
# Movie: Oldeuboi
# Mentioned Sentences: []
#
# Movie: Memento
# Mentioned Sentences: []
#
# Movie: Mononoke-hime
# Mentioned Sentences: []
#
# Movie: Once Upon a Time in America
# Mentioned Sentences: []
#
# Movie: Raiders of the Lost Ark
# Mentioned Sentences: []
#
# Movie: The Shining
# Mentioned Sentences: []
#
# Movie: Apocalypse Now
# Mentioned Sentences: []
#
# Movie: Alien
# Mentioned Sentences: ['An alien on Earth loses the only device he can use to communicate with his spaceship. His innocent nature and child-like questions force the country to evaluate the impact of religion on its people.', 'A research team in Antarctica is hunted by a shape-shifting alien that assumes the appearance of its victims.', "Earth's mightiest heroes must come together and learn to fight as a team if they are going to stop the mischievous Loki and his alien army from enslaving humanity.", 'A linguist works with the military to communicate with alien lifeforms after twelve mysterious spacecrafts appear around the world.', 'A soldier fighting aliens gets to relive the same day over and over again, the day restarting every time he dies.', 'A troubled child summons the courage to help a friendly alien escape Earth and return to his home world.', 'A small-town doctor learns that the population of his community is being replaced by emotionless alien duplicates.', 'An alien lands and tells the people of Earth that they must live peacefully or be destroyed as a danger to other planets.', 'A teenage hustler and a young man obsessed with alien abductions cross paths, together discovering a horrible, liberating truth.']
#
# Movie: Anand
# Mentioned Sentences: []
#
# Movie: Tengoku to jigoku
# Mentioned Sentences: []
#
# Movie: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# Mentioned Sentences: []
#
# Movie: Witness for the Prosecution
# Mentioned Sentences: []
#
# Movie: Paths of Glory
# Mentioned Sentences: []
#
# Movie: Rear Window
# Mentioned Sentences: []
#
# Movie: Sunset Blvd.
# Mentioned Sentences: []
#
# Movie: The Great Dictator
# Mentioned Sentences: []
#
# Movie: 1917
# Mentioned Sentences: ['April 6th, 1917. As a regiment assembles to wage war deep in enemy territory, two soldiers are assigned to race against time and deliver a message that will stop 1,600 men from walking straight into a deadly trap.']
#
# Movie: Tumbbad
# Mentioned Sentences: []
#
# Movie: Andhadhun
# Mentioned Sentences: []
#
# Movie: Drishyam
# Mentioned Sentences: []
#
# Movie: Jagten
# Mentioned Sentences: []
#
# Movie: Jodaeiye Nader az Simin
# Mentioned Sentences: []
#
# Movie: Incendies
# Mentioned Sentences: []
#
# Movie: Miracle in cell NO.7
# Mentioned Sentences: []
#
# Movie: Babam ve Oglum
# Mentioned Sentences: []
#
# Movie: Inglourious Basterds
# Mentioned Sentences: []
#
# Movie: Eternal Sunshine of the Spotless Mind
# Mentioned Sentences: []
#
# Movie: Amélie
# Mentioned Sentences: ['Amélie is an innocent and naive girl in Paris with her own sense of justice. She decides to help those around her and, along the way, discovers love.']
#
# Movie: Snatch
# Mentioned Sentences: []
#
# Movie: Requiem for a Dream
# Mentioned Sentences: []
#
# Movie: American Beauty
# Mentioned Sentences: []
#
# Movie: Good Will Hunting
# Mentioned Sentences: []
#
# Movie: Bacheha-Ye aseman
# Mentioned Sentences: []
#
# Movie: Toy Story
# Mentioned Sentences: []
#
# Movie: Braveheart
# Mentioned Sentences: []
#
# Movie: Reservoir Dogs
# Mentioned Sentences: []
#
# Movie: Full Metal Jacket
# Mentioned Sentences: []
#
# Movie: Idi i smotri
# Mentioned Sentences: []
#
# Movie: Aliens
# Mentioned Sentences: ['A soldier fighting aliens gets to relive the same day over and over again, the day restarting every time he dies.']
#
# Movie: Amadeus
# Mentioned Sentences: ["The life, success and troubles of Wolfgang Amadeus Mozart, as told by Antonio Salieri, the contemporaneous composer who was insanely jealous of Mozart's talent and claimed to have murdered him."]
#
# Movie: Scarface
# Mentioned Sentences: []
#
# Movie: Star Wars: Episode VI - Return of the Jedi
# Mentioned Sentences: []
#
# Movie: Das Boot
# Mentioned Sentences: []
#
# Movie: Taxi Driver
# Mentioned Sentences: ['A mentally unstable veteran works as a nighttime taxi driver in New York City, where the perceived decadence and sleaze fuels his urge for violent action by attempting to liberate a presidential campaign worker and an underage prostitute.']
#
# Movie: The Sting
# Mentioned Sentences: []
#
# Movie: A Clockwork Orange
# Mentioned Sentences: []
#
# Movie: 2001: A Space Odyssey
# Mentioned Sentences: []
#
# Movie: Per qualche dollaro in più
# Mentioned Sentences: []
#
# Movie: Lawrence of Arabia
# Mentioned Sentences: []
#
# Movie: The Apartment
# Mentioned Sentences: []
#
# Movie: North by Northwest
# Mentioned Sentences: []
#
# Movie: Vertigo
# Mentioned Sentences: []
#
# Movie: Singin' in the Rain
# Mentioned Sentences: []
#
# Movie: Ikiru
# Mentioned Sentences: []
#
# Movie: Ladri di biciclette
# Mentioned Sentences: []
#
# Movie: Double Indemnity
# Mentioned Sentences: []
#
# Movie: Citizen Kane
# Mentioned Sentences: []
#
# Movie: M - Eine Stadt sucht einen Mörder
# Mentioned Sentences: []
#
# Movie: Metropolis
# Mentioned Sentences: []
#
# Movie: The Kid
# Mentioned Sentences: []
#
# Movie: Chhichhore
# Mentioned Sentences: []
#
# Movie: Uri: The Surgical Strike
# Mentioned Sentences: []
#
# Movie: K.G.F: Chapter 1
# Mentioned Sentences: []
#
# Movie: Green Book
# Mentioned Sentences: []
#
# Movie: Three Billboards Outside Ebbing, Missouri
# Mentioned Sentences: []
#
# Movie: Talvar
# Mentioned Sentences: []
#
# Movie: Baahubali 2: The Conclusion
# Mentioned Sentences: []
#
# Movie: Klaus
# Mentioned Sentences: ["A simple act of kindness always sparks another, even in a frozen, faraway place. When Smeerensburg's new postman, Jesper, befriends toymaker Klaus, their gifts melt an age-old feud and deliver a sleigh full of holiday traditions."]
#
# Movie: Drishyam
# Mentioned Sentences: []
#
# Movie: Queen
# Mentioned Sentences: ['The story of the legendary British rock band Queen and lead singer Freddie Mercury, leading up to their famous performance at Live Aid (1985).', 'Two con artists try to swindle a stamp collector by selling him a sheet of counterfeit rare stamps (the "nine queens").', 'Incompetent police Detective Frank Drebin must foil an attempt to assassinate Queen Elizabeth II.']
#
# Movie: Mandariinid
# Mentioned Sentences: []
#
# Movie: Bhaag Milkha Bhaag
# Mentioned Sentences: []
#
# Movie: Gangs of Wasseypur
# Mentioned Sentences: []
#
# Movie: Udaan
# Mentioned Sentences: []
#
# Movie: Paan Singh Tomar
# Mentioned Sentences: ['The story of Paan Singh Tomar, an Indian athlete and seven-time national steeplechase champion who becomes one of the most feared dacoits in Chambal Valley after his retirement.']
#
# Movie: El secreto de sus ojos
# Mentioned Sentences: []
#
# Movie: Warrior
# Mentioned Sentences: ['Scottish warrior William Wallace leads his countrymen in a rebellion to free his homeland from the tyranny of King Edward I of England.', 'Warrior and pacifist Princess Nausicaä desperately struggles to prevent two warring nations from destroying themselves and their dying planet.', 'A group of intergalactic criminals must pull together to stop a fanatical warrior with plans to purge the universe.', 'A defense officer, Nameless, was summoned by the King of Qin regarding his success of terminating three warriors.', 'A family descended from Maori warriors is bedeviled by a violent father and the societal problems of being treated as outcasts.', 'A young Chinese warrior steals a sword from a famed swordsman and then escapes into a world of romantic adventure with a mysterious man in the frontier of the nation.', 'A team of commandos on a mission in a Central American jungle find themselves hunted by an extraterrestrial warrior.', "Outnumbered British soldiers do battle with Zulu warriors at Rorke's Drift.", 'In the near future, a charismatic leader summons the street gangs of New York City in a bid to take it over. When he is killed, The Warriors are falsely blamed and now must fight their way home while every other gang is hunting them down.']
#
# Movie: Shutter Island
# Mentioned Sentences: []
#
# Movie: Up
# Mentioned Sentences: ['In German-occupied Poland during World War II, industrialist Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis.', 'A criminal pleads insanity and is admitted to a mental institution, where he rebels against the oppressive nurse and rallies up the scared patients.', 'Following the Normandy Landings, a group of U.S. soldiers go behind enemy lines to retrieve a paratrooper whose brothers have been killed in action.', 'A former Roman General sets out to exact vengeance against the corrupt emperor who murdered his family and sent him into slavery.', 'A sole survivor tells of the twisty events leading up to a horrific gun battle on a boat, which began when five criminals met at a seemingly random police lineup.', 'In 1950, amid-st the ravages of the Korean War, Sergeant Süleyman stumbles upon a half-frozen little girl, with no parents and no help in sight. Frantic, scared and on the verge of death, ...                See full summary\xa0»', "A married couple are faced with a difficult decision - to improve the life of their child by moving to another country or to stay in Iran and look after a deteriorating parent who has Alzheimer's disease.", 'The family of a left-wing journalist is torn apart after the military coup of Turkey in 1980.', "In Nazi-occupied France during World War II, a plan to assassinate Nazi leaders by a group of Jewish U.S. soldiers coincides with a theatre owner's vengeful plans for the same.", 'When their relationship turns sour, a couple undergoes a medical procedure to have each other erased from their memories.', 'Unscrupulous boxing promoters, violent bookmakers, a Russian gangster, incompetent amateur robbers and supposedly Jewish jewelers fight to track down a priceless stolen diamond.', "A cowboy doll is profoundly threatened and jealous when a new spaceman figure supplants him as top toy in a boy's room.", 'Two grifters team up to pull off the ultimate con.', 'After discovering a mysterious artifact buried beneath the Lunar surface, mankind sets off on a quest to find its origins with help from intelligent supercomputer H.A.L. 9000.', 'Two bounty hunters with the same intentions team up to track down a Western outlaw.', 'A New York City advertising executive goes on the run after being mistaken for a government agent by a group of foreign spies.', 'Indian army special forces execute a covert operation, avenging the killing of fellow army men at their base by a terrorist group.', 'A retired legal counselor writes a novel hoping to find closure for one of his past unresolved homicide cases and for his unreciprocated love with his superior - both of which still haunt him decades later.', 'Based on the true story of Jordan Belfort, from his rise to a wealthy stock-broker living the high life to his fall involving crime, corruption and the federal government.', "The toys are mistakenly delivered to a day-care center instead of the attic right before Andy leaves for college, and it's up to Woody to convince the other toys that they weren't abandoned and to return home.", 'After training with his mentor, Batman begins his fight to free crime-ridden Gotham City from corruption.', 'As corruption grows in 1950s Los Angeles, three policemen - one strait-laced, one brutal, and one sleazy - investigate a series of murders with their own brand of justice.', 'A group of professional bank robbers start to feel the heat from police when they unknowingly leave a clue at their latest heist.', 'In 1938, after his father Professor Henry Jones, Sr. goes missing while pursuing the Holy Grail, Professor Henry "Indiana" Jones, Jr. finds himself up against Adolf Hitler\'s Nazis again to stop them from obtaining its powers.', 'In Medieval Japan, an elderly warlord retires, handing over his empire to his three sons. However, he vastly underestimates how the new-found power will corrupt them and cause them to turn on each other...and him.', ' ...
#
# Movie: The Wolf of Wall Street
# Mentioned Sentences: []
#
# Movie: Chak De! India
# Mentioned Sentences: []
#
# Movie: There Will Be Blood
# Mentioned Sentences: []
#
# Movie: Pan's Labyrinth
# Mentioned Sentences: []
#
# Movie: Toy Story 3
# Mentioned Sentences: []
#
# Movie: V for Vendetta
# Mentioned Sentences: []
#
# Movie: Rang De Basanti
# Mentioned Sentences: []
#
# Movie: Black
# Mentioned Sentences: ['The lives of guards on Death Row are affected by one of their charges: a black man accused of child murder and rape, yet who has a mysterious gift.', 'Atticus Finch, a lawyer in the Depression-era South, defends a black man against an undeserved rape charge, and his children against prejudice.', 'A man seeks answers about life, death, and the existence of God as he plays chess against the Grim Reaper during the Black Plague.', 'In the antebellum United States, Solomon Northup, a free black man from upstate New York, is abducted and sold into slavery.', 'Blacksmith Will Turner teams up with eccentric pirate "Captain" Jack Sparrow to save his love, the governor\'s daughter, from Jack\'s former pirate allies, who are now undead.', 'Following the death of her adoptive parents, a successful young black optometrist establishes contact with her biological mother -- a lonely white factory worker living in poverty in East London.', 'When two escaping American World War II prisoners are killed, the German P.O.W. camp barracks black marketeer, J.J. Sefton, is suspected of being an informer.', "The brash James T. Kirk tries to live up to his father's legacy with Mr. Spock keeping him in check as a vengeful Romulan from the future creates black holes to destroy the Federation one planet at a time.", 'A black police detective is asked to investigate a murder in a racially hostile southern town.', "Private detective Philip Marlowe is hired by a wealthy family. Before the complex case is over, he's seen murder, blackmail, and what might be love.", 'An American expat tries to sell off his highly profitable marijuana empire in London, triggering plots, schemes, bribery and blackmail in an attempt to steal his domain out from under him.', "Robert Gould Shaw leads the U.S. Civil War's first all-black volunteer company, fighting prejudices from both his own Union Army, and the Confederates.", 'A black Southern woman struggles to find her identity after suffering abuse from her father and others over four decades.', 'As Steve Rogers struggles to embrace his role in the modern world, he teams up with a fellow Avenger and S.H.I.E.L.D agent, Black Widow, to battle a new threat from history: an assassin known as the Winter Soldier.', 'Biographical epic of the controversial and influential Black Nationalist leader, from his early life and career as a small-time gangster, to his ministry as a member of the Nation of Islam.', 'In order to ruin a western town, a corrupt politician appoints a black Sheriff, who promptly becomes his most formidable adversary.', 'Evan Treborn suffers blackouts during significant events of his life. As he grows up, he finds a way to remember these lost memories and a supernatural way to alter his life by reading his journal.', 'Post-apocalyptic surrealist black comedy about the landlord of an apartment building who occasionally prepares a delicacy for his odd tenants.']
#
# Movie: Batman Begins
# Mentioned Sentences: ['After training with his mentor, Batman begins his fight to free crime-ridden Gotham City from corruption.']
#
# Movie: Swades: We, the People
# Mentioned Sentences: []
#
# Movie: Der Untergang
# Mentioned Sentences: []
#
# Movie: Hauru no ugoku shiro
# Mentioned Sentences: []
#
# Movie: A Beautiful Mind
# Mentioned Sentences: []
#
# Movie: Hera Pheri
# Mentioned Sentences: []
#
# Movie: Lock, Stock and Two Smoking Barrels
# Mentioned Sentences: []
#
# Movie: L.A. Confidential
# Mentioned Sentences: []
#
# Movie: Eskiya
# Mentioned Sentences: []
#
# Movie: Heat
# Mentioned Sentences: ["The real life of one of America's foremost founding fathers and first Secretary of the Treasury, Alexander Hamilton. Captured live on Broadway from the Richard Rodgers Theater with the original Broadway cast.", "In Nazi-occupied France during World War II, a plan to assassinate Nazi leaders by a group of Jewish U.S. soldiers coincides with a theatre owner's vengeful plans for the same.", 'A group of professional bank robbers start to feel the heat from police when they unknowingly leave a clue at their latest heist.', 'A seemingly timid but secretly ruthless ingénue insinuates herself into the lives of an aging Broadway star and her circle of theater friends.', 'Concurrent theatrical ending of the TV series Shin seiki evangerion (1995).', 'A Mumbai teenager reflects on his life after being accused of cheating on the Indian version of "Who Wants to be a Millionaire?".', "A man who loves games and theater invites his wife's lover to meet him, setting up a battle of wits with potentially deadly results.", 'Meeting a stranger in a railway station, a woman is tempted to cheat on her husband.', "Ted Kramer's wife leaves him, allowing for a lost bond to be rediscovered between Ted and his son, Billy. But a heated custody battle ensues over the divorced couple's son, deepening the wounds left by the separation.", 'A theatre director struggles with his work, and the women in his life, as he creates a life-size replica of New York City inside a warehouse as part of his new play.']
#
# Movie: Casino
# Mentioned Sentences: ['A tale of greed, deception, money, power, and murder occur between two best friends: a mafia enforcer and a casino executive compete against each other over a gambling empire, and over a fast-living and fast-loving socialite.', 'After earning 00 status and a licence to kill, Secret Agent James Bond sets out on his first mission as 007. Bond must defeat a private banker funding terrorists in a high-stakes game of poker at Casino Royale, Montenegro.', 'Danny Ocean and his ten accomplices plan to rob three Las Vegas casinos simultaneously.', "A small-time gambler hired to work in a Buenos Aires casino discovers his employer's new wife is his former lover."]
#
# Movie: Andaz Apna Apna
# Mentioned Sentences: []
#
# Movie: Unforgiven
# Mentioned Sentences: []
#
# Movie: Indiana Jones and the Last Crusade
# Mentioned Sentences: []
#
# Movie: Dom za vesanje
# Mentioned Sentences: []
#
# Movie: Tonari no Totoro
# Mentioned Sentences: []
#
# Movie: Die Hard
# Mentioned Sentences: []
#
# Movie: Ran
# Mentioned Sentences: ["An organized crime dynasty's aging patriarch transfers control of his clandestine empire to his reluctant son.", 'When a beautiful stranger leads computer hacker Neo to a forbidding underworld, he discovers the shocking truth--the life he knows is the elaborate deception of an evil cyber-intelligence.', 'Nedumaaran Rajangam "Maara" sets out to make the common man fly and in the process takes on the world\'s most capital intensive industry and several enemies who stand in his way.', 'Two detectives, a rookie and a veteran, hunt a serial killer who uses the seven deadly sins as his motives.', 'A sole survivor tells of the twisty events leading up to a horrific gun battle on a boat, which began when five criminals met at a seemingly random police lineup.', 'A mysterious stranger with a harmonica joins forces with a notorious desperado to protect a beautiful widow from a ruthless assassin working for the railroad.', 'In 1950, amid-st the ravages of the Korean War, Sergeant Süleyman stumbles upon a half-frozen little girl, with no parents and no help in sight. Frantic, scared and on the verge of death, ...                See full summary\xa0»', 'Two strangers find themselves linked in a bizarre way. When a connection forms, will distance be the only thing to keep them apart?', "Aspiring musician Miguel, confronted with his family's ancestral ban on music, enters the Land of the Dead to find his great-great-grandfather, a legendary singer.", 'After a space merchant vessel receives an unknown transmission as a distress call, one of the crew is attacked by a mysterious life form and they soon realize that its life cycle has merely begun.', "An executive of a shoe company becomes a victim of extortion when his chauffeur's son is kidnapped and held for ransom.", 'An insane general triggers a path to nuclear holocaust that a War Room full of politicians and generals frantically tries to stop.', 'A veteran British barrister must defend his client in a murder trial that has surprise after surprise.', "A married couple are faced with a difficult decision - to improve the life of their child by moving to another country or to stay in Iran and look after a deteriorating parent who has Alzheimer's disease.", "In Nazi-occupied France during World War II, a plan to assassinate Nazi leaders by a group of Jewish U.S. soldiers coincides with a theatre owner's vengeful plans for the same.", 'Scottish warrior William Wallace leads his countrymen in a rebellion to free his homeland from the tyranny of King Edward I of England.', "The life, success and troubles of Wolfgang Amadeus Mozart, as told by Antonio Salieri, the contemporaneous composer who was insanely jealous of Mozart's talent and claimed to have murdered him.", 'In 1980 Miami, a determined Cuban immigrant takes over a drug cartel and succumbs to greed.', 'A mentally unstable veteran works as a nighttime taxi driver in New York City, where the perceived decadence and sleaze fuels his urge for violent action by attempting to liberate a presidential campaign worker and an underage prostitute.', 'A silent film production company and cast make a difficult transition to sound.', 'An insurance representative lets himself be talked by a seductive housewife into a murder/insurance fraud scheme that arouses the suspicion of an insurance investigator.', "Following the death of publishing tycoon Charles Foster Kane, reporters scramble to uncover the meaning of his final utterance; 'Rosebud'.", "The youngest son of an alcoholic former boxer returns home, where he's trained by his father for competition in a mixed martial arts tournament - a path that puts the fighter on a collision course with his estranged, older brother.", 'In 1954, a U.S. Marshal investigates the disappearance of a murderer who escaped from a hospital for the criminally insane.', 'In a future British tyranny, a shadowy freedom fighter, known only by the alias of "V", plots to overthrow it with the help of a you ...
#
# Movie: Raging Bull
# Mentioned Sentences: []
#
# Movie: Stalker
# Mentioned Sentences: []
#
# Movie: Höstsonaten
# Mentioned Sentences: []
#
# Movie: The Message
# Mentioned Sentences: []
#
# Movie: Sholay
# Mentioned Sentences: []
#
# Movie: Monty Python and the Holy Grail
# Mentioned Sentences: []
#
# Movie: The Great Escape
# Mentioned Sentences: []
#
# Movie: To Kill a Mockingbird
# Mentioned Sentences: []
#
# Movie: Yôjinbô
# Mentioned Sentences: []
#
# Movie: Judgment at Nuremberg
# Mentioned Sentences: []
#
# Movie: Some Like It Hot
# Mentioned Sentences: []
#
# Movie: Smultronstället
# Mentioned Sentences: []
#
# Movie: Det sjunde inseglet
# Mentioned Sentences: []
#
# Movie: Du rififi chez les hommes
# Mentioned Sentences: []
#
# Movie: Dial M for Murder
# Mentioned Sentences: []
#
# Movie: Tôkyô monogatari
# Mentioned Sentences: []
#
# Movie: Rashômon
# Mentioned Sentences: []
#
# Movie: All About Eve
# Mentioned Sentences: []
#
# Movie: The Treasure of the Sierra Madre
# Mentioned Sentences: []
#
# Movie: To Be or Not to Be
# Mentioned Sentences: []
#
# Movie: The Gold Rush
# Mentioned Sentences: []
#
# Movie: Sherlock Jr.
# Mentioned Sentences: []
#
# Movie: Portrait de la jeune fille en feu
# Mentioned Sentences: []
#
# Movie: Pink
# Mentioned Sentences: []
#
# Movie: Koe no katachi
# Mentioned Sentences: []
#
# Movie: Contratiempo
# Mentioned Sentences: []
#
# Movie: Ah-ga-ssi
# Mentioned Sentences: []
#
# Movie: Mommy
# Mentioned Sentences: []
#
# Movie: Haider
# Mentioned Sentences: []
#
# Movie: Logan
# Mentioned Sentences: ['Retired Old West gunslinger William Munny reluctantly takes on one last job, with the help of his old partner Ned Logan and a young man, The "Schofield Kid."', 'In a future where mutants are nearly extinct, an elderly and weary Logan leads a quiet life. But when Laura, a mutant child pursued by scientists, comes to him for help, he must get her to safety.']
#
# Movie: Room
# Mentioned Sentences: ['An insane general triggers a path to nuclear holocaust that a War Room full of politicians and generals frantically tries to stop.', "A cowboy doll is profoundly threatened and jealous when a new spaceman figure supplants him as top toy in a boy's room.", 'A guide leads two men through an area known as the Zone to find a room that grants wishes.', 'A French boarding school run by priests seems to be a haven from World War II until a new student arrives. He becomes the roommate of the top student in his class. Rivals at first, the roommates form a bond and share a secret.', 'A substitute teacher who drifts from classroom to classroom finds a connection to the students and teachers during his latest assignment.', 'Five oddball criminals planning a bank robbery rent rooms on a cul-de-sac from an octogenarian widow under the pretext that they are classical musicians.', "Two strangers awaken in a room with no recollection of how they got there, and soon discover they're pawns in a deadly game perpetrated by a notorious serial killer."]
#
# Movie: Relatos salvajes
# Mentioned Sentences: []
#
# Movie: Soul
# Mentioned Sentences: ['A butler who sacrificed body and soul to service in the years leading up to World War II realizes too late how misguided his loyalty was to his lordly employer.']
#
# Movie: Kis Uykusu
# Mentioned Sentences: []
#
# Movie: PK
# Mentioned Sentences: ['A shopkeeper takes God to court when his shop is destroyed by an earthquake.', 'Rupert Pupkin is a passionate yet unsuccessful comic who craves nothing more than to be in the spotlight and to achieve this, he stalks and kidnaps his idol to take the spotlight for himself.']
#
# Movie: OMG: Oh My God!
# Mentioned Sentences: []
#
# Movie: The Grand Budapest Hotel
# Mentioned Sentences: []
#
# Movie: Gone Girl
# Mentioned Sentences: []
#
# Movie: Ôkami kodomo no Ame to Yuki
# Mentioned Sentences: []
#
# Movie: Hacksaw Ridge
# Mentioned Sentences: []
#
# Movie: Inside Out
# Mentioned Sentences: []
#
# Movie: Barfi!
# Mentioned Sentences: []
#
# Movie: 12 Years a Slave
# Mentioned Sentences: []
#
# Movie: Rush
# Mentioned Sentences: ['Two terminally ill patients escape from a hospital, steal a car and rush towards the sea.', 'The extracurricular king of Rushmore Preparatory School is put on academic probation.']
#
# Movie: Ford v Ferrari
# Mentioned Sentences: []
#
# Movie: Spotlight
# Mentioned Sentences: ["With his wife's disappearance having become the focus of an intense media circus, a man sees the spotlight turned on him when it's suspected that he may not be innocent.", 'Rupert Pupkin is a passionate yet unsuccessful comic who craves nothing more than to be in the spotlight and to achieve this, he stalks and kidnaps his idol to take the spotlight for himself.']
#
# Movie: Song of the Sea
# Mentioned Sentences: []
#
# Movie: Kahaani
# Mentioned Sentences: []
#
# Movie: Zindagi Na Milegi Dobara
# Mentioned Sentences: []
#
# Movie: Prisoners
# Mentioned Sentences: ['Allied prisoners of war plan for several hundred of their number to escape from a German camp during World War II.', 'In a post-apocalyptic wasteland, a woman rebels against a tyrannical ruler in search for her homeland with the aid of a group of female prisoners, a psychotic worshiper, and a drifter named Max.', 'When two escaping American World War II prisoners are killed, the German P.O.W. camp barracks black marketeer, J.J. Sefton, is suspected of being an informer.', 'For two weeks, 20 male participants are hired to play prisoners and guards in a prison. The "prisoners" have to follow seemingly mild rules, and the "guards" are told to retain order without using physical violence.']
#
# Movie: Mad Max: Fury Road
# Mentioned Sentences: []
#
# Movie: A Wednesday
# Mentioned Sentences: ['A retiring police officer reminisces about the most astounding day of his career. About a case that was never filed but continues to haunt him in his memories - the case of a man and a Wednesday.']
#
# Movie: Gran Torino
# Mentioned Sentences: ["Disgruntled Korean War veteran Walt Kowalski sets out to reform his neighbor, Thao Lor, a Hmong teenager who tried to steal Kowalski's prized possession: a 1972 Gran Torino."]
#
# Movie: Harry Potter and the Deathly Hallows: Part 2
# Mentioned Sentences: []
#
# Movie: Okuribito
# Mentioned Sentences: []
#
# Movie: Hachi: A Dog's Tale
# Mentioned Sentences: []
#
# Movie: Mary and Max
# Mentioned Sentences: []
#
# Movie: How to Train Your Dragon
# Mentioned Sentences: []
#
# Movie: Into the Wild
# Mentioned Sentences: []
#
# Movie: No Country for Old Men
# Mentioned Sentences: []
#
# Movie: Lage Raho Munna Bhai
# Mentioned Sentences: []
#
# Movie: Million Dollar Baby
# Mentioned Sentences: []
#
# Movie: Hotel Rwanda
# Mentioned Sentences: []
#
# Movie: Taegukgi hwinalrimyeo
# Mentioned Sentences: []
#
# Movie: Before Sunset
# Mentioned Sentences: []
#
# Movie: Munna Bhai M.B.B.S.
# Mentioned Sentences: []
#
# Movie: Salinui chueok
# Mentioned Sentences: []
#
# Movie: Dil Chahta Hai
# Mentioned Sentences: []
#
# Movie: Kill Bill: Vol. 1
# Mentioned Sentences: []
#
# Movie: Finding Nemo
# Mentioned Sentences: []
#
# Movie: Catch Me If You Can
# Mentioned Sentences: []
#
# Movie: Amores perros
# Mentioned Sentences: []
#
# Movie: Monsters, Inc.
# Mentioned Sentences: []
#
# Movie: Shin seiki Evangelion Gekijô-ban: Air/Magokoro wo, kimi ni
# Mentioned Sentences: []
#
# Movie: Lagaan: Once Upon a Time in India
# Mentioned Sentences: []
#
# Movie: The Sixth Sense
# Mentioned Sentences: []
#
# Movie: La leggenda del pianista sull'oceano
# Mentioned Sentences: []
#
# Movie: The Truman Show
# Mentioned Sentences: []
#
# Movie: Crna macka, beli macor
# Mentioned Sentences: []
#
# Movie: The Big Lebowski
# Mentioned Sentences: []
#
# Movie: Fa yeung nin wah
# Mentioned Sentences: []
#
# Movie: Trainspotting
# Mentioned Sentences: []
#
# Movie: Fargo
# Mentioned Sentences: []
#
# Movie: Underground
# Mentioned Sentences: ['An insomniac office worker and a devil-may-care soapmaker form an underground fight club that evolves into something much, much more.', 'A group of Serbian socialists prepares for the war in a surreal underground filled by parties, tragedies, love and hate.']
#
# Movie: La haine
# Mentioned Sentences: []
#
# Movie: Dilwale Dulhania Le Jayenge
# Mentioned Sentences: []
#
# Movie: Before Sunrise
# Mentioned Sentences: []
#
# Movie: Trois couleurs: Rouge
# Mentioned Sentences: []
#
# Movie: Chung Hing sam lam
# Mentioned Sentences: []
#
# Movie: Jurassic Park
# Mentioned Sentences: []
#
# Movie: In the Name of the Father
# Mentioned Sentences: []
#
# Movie: Ba wang bie ji
# Mentioned Sentences: []
#
# Movie: Dà hóng denglong gaogao guà
# Mentioned Sentences: []
#
# Movie: Dead Poets Society
# Mentioned Sentences: []
#
# Movie: Stand by Me
# Mentioned Sentences: []
#
# Movie: Platoon
# Mentioned Sentences: []
#
# Movie: Paris, Texas
# Mentioned Sentences: []
#
# Movie: Kaze no tani no Naushika
# Mentioned Sentences: []
#
# Movie: The Thing
# Mentioned Sentences: []
#
# Movie: Pink Floyd: The Wall
# Mentioned Sentences: []
#
# Movie: Fitzcarraldo
# Mentioned Sentences: []
#
# Movie: Fanny och Alexander
# Mentioned Sentences: []
#
# Movie: Blade Runner
# Mentioned Sentences: ['A blade runner must pursue and terminate four replicants who stole a ship in space, and have returned to Earth to find their creator.', "Young Blade Runner K's discovery of a long-buried secret leads him to track down former Blade Runner Rick Deckard, who's been missing for thirty years."]
#
# Movie: The Elephant Man
# Mentioned Sentences: []
#
# Movie: Life of Brian
# Mentioned Sentences: []
#
# Movie: The Deer Hunter
# Mentioned Sentences: []
#
# Movie: Rocky
# Mentioned Sentences: ['The former World Heavyweight Champion Rocky Balboa serves as a trainer and mentor to Adonis Johnson, the son of his late friend and former rival Apollo Creed.']
#
# Movie: Network
# Mentioned Sentences: ["A television network cynically exploits a deranged former anchor's ravings and revelations about the news media for its own profit.", 'As Harvard student Mark Zuckerberg creates the social networking site that would become known as Facebook, he is sued by the twins who claimed he stole their idea, and by the co-founder who was later squeezed out of the business.']
#
# Movie: Barry Lyndon
# Mentioned Sentences: []
#
# Movie: Zerkalo
# Mentioned Sentences: []
#
# Movie: Chinatown
# Mentioned Sentences: []
#
# Movie: Paper Moon
# Mentioned Sentences: []
#
# Movie: Viskningar och rop
# Mentioned Sentences: []
#
# Movie: Solaris
# Mentioned Sentences: []
#
# Movie: Le samouraï
# Mentioned Sentences: []
#
# Movie: Cool Hand Luke
# Mentioned Sentences: []
#
# Movie: Persona
# Mentioned Sentences: ['A former police detective juggles wrestling with his personal demons and becoming obsessed with a hauntingly beautiful woman.', "A mother personally challenges the local authorities to solve her daughter's murder when they fail to catch the culprit.", 'A dying man in his forties remembers his past. His childhood, his mother, the war, personal moments and things that tell of the recent history of all the Russian nation.', 'A nurse is put in charge of a mute actress and finds that their personae are melding together.', "Astronaut Sam Bell has a quintessentially personal encounter toward the end of his three-year stint on the Moon, where he, working alongside his computer, GERTY, sends back to Earth parcels of a resource that has helped diminish our planet's power problems.", 'A research chemist comes under personal and professional attack when he decides to appear in a 60 Minutes exposé on Big Tobacco.', 'Nishi leaves the police in the face of harrowing personal and professional difficulties. Spiraling into depression, he makes questionable decisions.', 'A naive hustler travels from Texas to New York City to seek personal fortune, finding a new friend in the process.', "James Bond's loyalty to M is tested when her past comes back to haunt her. When MI6 comes under attack, 007 must track down and destroy the threat, no matter how personal the cost.", 'A high-school girl named Makoto acquires the power to travel back in time, and decides to use it for her own personal benefits. Little does she know that she is affecting the lives of others just as much as she is her own.', "Based on the events of the brutal Ugandan dictator Idi Amin's regime as seen by his personal physician during the 1970s.", 'A profile of Ian Curtis, the enigmatic singer of Joy Division whose personal, professional, and romantic troubles led him to commit suicide at the age of 23.', "The Guardians struggle to keep together as a team while dealing with their personal family issues, notably Star-Lord's encounter with his father the ambitious celestial being Ego.", "Two Boston area detectives investigate a little girl's kidnapping, which ultimately turns into a crisis both professionally and personally.", 'When his only friend dies, a man born with dwarfism moves to rural New Jersey to live a life of solitude, only to meet a chatty hot dog vendor and a woman dealing with her own personal loss.']
#
# Movie: Andrei Rublev
# Mentioned Sentences: ['The life, times and afflictions of the fifteenth-century Russian iconographer St. Andrei Rublev.']
#
# Movie: La battaglia di Algeri
# Mentioned Sentences: []
#
# Movie: El ángel exterminador
# Mentioned Sentences: []
#
# Movie: What Ever Happened to Baby Jane?
# Mentioned Sentences: []
#
# Movie: Sanjuro
# Mentioned Sentences: []
#
# Movie: The Man Who Shot Liberty Valance
# Mentioned Sentences: []
#
# Movie: Ivanovo detstvo
# Mentioned Sentences: []
#
# Movie: Jungfrukällan
# Mentioned Sentences: []
#
# Movie: Inherit the Wind
# Mentioned Sentences: []
#
# Movie: Les quatre cents coups
# Mentioned Sentences: []
#
# Movie: Ben-Hur
# Mentioned Sentences: []
#
# Movie: Kakushi-toride no san-akunin
# Mentioned Sentences: []
#
# Movie: Le notti di Cabiria
# Mentioned Sentences: []
#
# Movie: Kumonosu-jô
# Mentioned Sentences: []
#
# Movie: The Bridge on the River Kwai
# Mentioned Sentences: []
#
# Movie: On the Waterfront
# Mentioned Sentences: []
#
# Movie: Le salaire de la peur
# Mentioned Sentences: []
#
# Movie: Ace in the Hole
# Mentioned Sentences: []
#
# Movie: White Heat
# Mentioned Sentences: []
#
# Movie: The Third Man
# Mentioned Sentences: []
#
# Movie: The Red Shoes
# Mentioned Sentences: []
#
# Movie: The Shop Around the Corner
# Mentioned Sentences: []
#
# Movie: Rebecca
# Mentioned Sentences: []
#
# Movie: Mr. Smith Goes to Washington
# Mentioned Sentences: []
#
# Movie: Gone with the Wind
# Mentioned Sentences: []
#
# Movie: La Grande Illusion
# Mentioned Sentences: []
#
# Movie: It Happened One Night
# Mentioned Sentences: []
#
# Movie: La passion de Jeanne d'Arc
# Mentioned Sentences: []
#
# Movie: The Circus
# Mentioned Sentences: []
#
# Movie: Sunrise: A Song of Two Humans
# Mentioned Sentences: []
#
# Movie: The General
# Mentioned Sentences: []
#
# Movie: Das Cabinet des Dr. Caligari
# Mentioned Sentences: []
#
# Movie: Badhaai ho
# Mentioned Sentences: []
#
# Movie: Togo
# Mentioned Sentences: ['The story of Togo, the sled dog who led the 1925 serum run yet was considered by most to be too small and weak to lead such an intense race.']
#
# Movie: Airlift
# Mentioned Sentences: []
#
# Movie: Bajrangi Bhaijaan
# Mentioned Sentences: []
#
# Movie: Baby
# Mentioned Sentences: ['A baby boy, discovered in 1900 on an ocean liner, grows into a musical prodigy, never setting foot on land.', 'A prep school student needing money agrees to "babysit" a blind man, but the job is not at all what he anticipated.', 'A young couple trying for a baby move into a fancy apartment surrounded by peculiar neighbors.', 'On Christmas Eve, three homeless people living on the streets of Tokyo discover a newborn baby among the trash and set out to find its parents.', 'While trying to secure a $1 million donation for his museum, a befuddled paleontologist is pursued by a flighty and often irritating heiress and her pet leopard, Baby.']
#
# Movie: La La Land
# Mentioned Sentences: []
#
# Movie: Lion
# Mentioned Sentences: ['Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.', 'Scottish warrior William Wallace leads his countrymen in a rebellion to free his homeland from the tyranny of King Edward I of England.', 'Violence and mayhem ensue after a hunter stumbles upon a drug deal gone wrong and more than two million dollars in cash near the Rio Grande.', 'Jeff "The Dude" Lebowski, mistaken for a millionaire of the same name, seeks restitution for his ruined rug and enlists his bowling buddies to help get it.', 'A Mumbai teenager reflects on his life after being accused of cheating on the Indian version of "Who Wants to be a Millionaire?".', 'After being held captive in an Afghan cave, billionaire engineer Tony Stark creates a unique weaponized suit of armor to fight evil.', "A journalist is trapped in Cambodia during tyrant Pol Pot's bloody 'Year Zero' cleansing campaign, which claimed the lives of two million 'undesirable' civilians.", 'While trying to secure a $1 million donation for his museum, a befuddled paleontologist is pursued by a flighty and often irritating heiress and her pet leopard, Baby.', 'An aging, booze-addled father makes the trip from Montana to Nebraska with his estranged son in order to claim a million-dollar Mega Sweepstakes Marketing prize.', 'The story of two men on different sides of a prison riot -- the inmate leading the rebellion and the young guard trapped in the revolt, who poses as a prisoner in a desperate attempt to survive the ordeal.']
#
# Movie: The Martian
# Mentioned Sentences: []
#
# Movie: Zootopia
# Mentioned Sentences: []
#
# Movie: Bãhubali: The Beginning
# Mentioned Sentences: []
#
# Movie: Kaguyahime no monogatari
# Mentioned Sentences: []
#
# Movie: Wonder
# Mentioned Sentences: []
#
# Movie: Gully Boy
# Mentioned Sentences: []
#
# Movie: Special Chabbis
# Mentioned Sentences: []
#
# Movie: Short Term 12
# Mentioned Sentences: []
#
# Movie: Serbuan maut 2: Berandal
# Mentioned Sentences: []
#
# Movie: The Imitation Game
# Mentioned Sentences: []
#
# Movie: Guardians of the Galaxy
# Mentioned Sentences: []
#
# Movie: Blade Runner 2049
# Mentioned Sentences: []
#
# Movie: Her
# ...
#
# Movie: Lost in Translation
# Mentioned Sentences: []
#
# Movie: Harry Potter and the Goblet of Fire
# Mentioned Sentences: []
#
# Movie: Man on Fire
# Mentioned Sentences: []
#
# Movie: Coraline
# Mentioned Sentences: []
#
# Movie: The Last Samurai
# Mentioned Sentences: []
#
# Movie: The Magdalene Sisters
# Mentioned Sentences: []
#
# Movie: Good Bye Lenin!
# Mentioned Sentences: []
#
# Movie: In America
# Mentioned Sentences: ['World War II American Army Medic Desmond T. Doss, who served during the Battle of Okinawa, refuses to kill people, and becomes the first man in American history to receive the Medal of Honor without firing a shot.', "Political involvement in the Avengers' affairs causes a rift between Captain America and Iron Man."]
#
# Movie: I Am Sam
# Mentioned Sentences: []
#
# Movie: Adaptation.
# Mentioned Sentences: []
#
# Movie: Black Hawk Down
# Mentioned Sentences: []
#
# Movie: Road to Perdition
# Mentioned Sentences: []
#
# Movie: Das Experiment
# Mentioned Sentences: []
#
# Movie: Billy Elliot
# Mentioned Sentences: []
#
# Movie: Hedwig and the Angry Inch
# Mentioned Sentences: []
#
# Movie: Ocean's Eleven
# Mentioned Sentences: []
#
# Movie: Vampire Hunter D: Bloodlust
# Mentioned Sentences: []
#
# Movie: O Brother, Where Art Thou?
# Mentioned Sentences: []
#
# Movie: Interstate 60: Episodes of the Road
# Mentioned Sentences: []
#
# Movie: South Park: Bigger, Longer & Uncut
# Mentioned Sentences: []
#
# Movie: Office Space
# Mentioned Sentences: []
#
# Movie: Happiness
# Mentioned Sentences: ['A young man in a small Midwestern town struggles to care for his mentally-disabled younger brother and morbidly obese mother while attempting to pursue his own happiness.']
#
# Movie: Training Day
# Mentioned Sentences: []
#
# Movie: Rushmore
# Mentioned Sentences: ['The extracurricular king of Rushmore Preparatory School is put on academic probation.']
#
# Movie: Abre los ojos
# Mentioned Sentences: []
#
# Movie: Being John Malkovich
# Mentioned Sentences: []
#
# Movie: As Good as It Gets
# Mentioned Sentences: []
#
# Movie: The Fifth Element
# Mentioned Sentences: []
#
# Movie: Le dîner de cons
# Mentioned Sentences: []
#
# Movie: Donnie Brasco
# Mentioned Sentences: []
#
# Movie: Shine
# Mentioned Sentences: ['A film crew goes to a tropical island for an exotic location shoot and discovers a colossal ape who takes a shine to their female blonde star. He is then captured and brought back to New York City for public exhibition.']
#
# Movie: Primal Fear
# Mentioned Sentences: []
#
# Movie: Hamlet
# Mentioned Sentences: ['Hamlet, Prince of Denmark, returns home to find his father murdered and his mother remarrying the murderer, his uncle. Meanwhile, war is brewing.']
#
# Movie: A Little Princess
# Mentioned Sentences: []
#
# Movie: Do lok tin si
# Mentioned Sentences: []
#
# Movie: Il postino
# Mentioned Sentences: []
#
# Movie: Clerks
# Mentioned Sentences: ['A day in the lives of two convenience clerks named Dante and Randal as they annoy customers, discuss movies, and play hockey on the store roof.']
#
# Movie: Short Cuts
# Mentioned Sentences: []
#
# Movie: Philadelphia
# Mentioned Sentences: ['Following an ever-growing epidemic of zombies that have risen from the dead, two Philadelphia S.W.A.T. team members, a traffic reporter, and his television executive girlfriend seek refuge in a secluded shopping mall.']
#
# Movie: The Muppet Christmas Carol
# Mentioned Sentences: []
#
# Movie: Malcolm X
# Mentioned Sentences: []
#
# Movie: The Last of the Mohicans
# Mentioned Sentences: []
#
# Movie: Kurenai no buta
# Mentioned Sentences: []
#
# Movie: Glengarry Glen Ross
# Mentioned Sentences: []
#
# Movie: A Few Good Men
# Mentioned Sentences: []
#
# Movie: Fried Green Tomatoes
# Mentioned Sentences: []
#
# Movie: Barton Fink
# Mentioned Sentences: []
#
# Movie: Miller's Crossing
# Mentioned Sentences: []
#
# Movie: Who Framed Roger Rabbit
# Mentioned Sentences: []
#
# Movie: Spoorloos
# Mentioned Sentences: []
#
# Movie: Withnail & I
# Mentioned Sentences: []
#
# Movie: The Last Emperor
# Mentioned Sentences: []
#
# Movie: Empire of the Sun
# Mentioned Sentences: []
#
# Movie: Der Name der Rose
# Mentioned Sentences: []
#
# Movie: Blue Velvet
# Mentioned Sentences: []
#
# Movie: The Purple Rose of Cairo
# Mentioned Sentences: []
#
# Movie: After Hours
# Mentioned Sentences: []
#
# Movie: Zelig
# Mentioned Sentences: []
#
# Movie: The Verdict
# Mentioned Sentences: []
#
# Movie: Star Trek II: The Wrath of Khan
# Mentioned Sentences: []
#
# Movie: First Blood
# Mentioned Sentences: []
#
# Movie: Ordinary People
# Mentioned Sentences: []
#
# Movie: Airplane!
# Mentioned Sentences: []
#
# Movie: Rupan sansei: Kariosutoro no shiro
# Mentioned Sentences: []
#
# Movie: Halloween
# Mentioned Sentences: ['Jack Skellington, king of Halloween Town, discovers Christmas Town, but his attempts to bring Christmas to his home causes confusion.', 'Fifteen years after murdering his sister on Halloween night 1963, Michael Myers escapes from a mental hospital and returns to the small town of Haddonfield, Illinois to kill again.']
#
# Movie: Le locataire
# Mentioned Sentences: []
#
# Movie: Love and Death
# Mentioned Sentences: []
#
# Movie: The Taking of Pelham One Two Three
# Mentioned Sentences: []
#
# Movie: Blazing Saddles
# Mentioned Sentences: []
#
# Movie: Serpico
# Mentioned Sentences: ['An honest New York cop named Frank Serpico blows the whistle on rampant corruption in the force only to have his comrades turn against him.']
#
# Movie: Enter the Dragon
# Mentioned Sentences: []
#
# Movie: Deliverance
# Mentioned Sentences: []
#
# Movie: The French Connection
# Mentioned Sentences: []
#
# Movie: Dirty Harry
# Mentioned Sentences: []
#
# Movie: Where Eagles Dare
# Mentioned Sentences: []
#
# Movie: The Odd Couple
# Mentioned Sentences: []
#
# Movie: The Dirty Dozen
# Mentioned Sentences: []
#
# Movie: Belle de jour
# Mentioned Sentences: []
#
# Movie: A Man for All Seasons
# Mentioned Sentences: []
#
# Movie: Repulsion
# Mentioned Sentences: []
#
# Movie: Zulu
# Mentioned Sentences: ["Outnumbered British soldiers do battle with Zulu warriors at Rorke's Drift."]
#
# Movie: Goldfinger
# Mentioned Sentences: []
#
# Movie: The Birds
# Mentioned Sentences: []
#
# Movie: Cape Fear
# Mentioned Sentences: []
#
# Movie: Peeping Tom
# Mentioned Sentences: []
#
# Movie: The Magnificent Seven
# Mentioned Sentences: []
#
# Movie: Les yeux sans visage
# Mentioned Sentences: []
#
# Movie: Invasion of the Body Snatchers
# Mentioned Sentences: []
#
# Movie: Rebel Without a Cause
# Mentioned Sentences: []
#
# Movie: The Ladykillers
# Mentioned Sentences: []
#
# Movie: Sabrina
# Mentioned Sentences: []
#
# Movie: The Quiet Man
# Mentioned Sentences: []
#
# Movie: The Day the Earth Stood Still
# Mentioned Sentences: []
#
# Movie: The African Queen
# Mentioned Sentences: []
#
# Movie: Gilda
# Mentioned Sentences: []
#
# Movie: Fantasia
# Mentioned Sentences: []
#
# Movie: The Invisible Man
# Mentioned Sentences: []
#
# Movie: Dark Waters
# Mentioned Sentences: []
#
# Movie: Searching
# Mentioned Sentences: ['Two friends are searching for their long lost companion. They revisit their college days and recall the memories of their friend who inspired them to think differently, even as the rest of the world called them "idiots".', 'Two Americans searching for work in Mexico convince an old prospector to help them mine for gold in the Sierra Madre Mountains.', 'Jason Bourne dodges a ruthless C.I.A. official and his Agents from a new assassination program while searching for the origins of his life as a trained killer.', "Neal Oliver, a very confused young man and an artist, takes a journey of a lifetime on a highway I60 that doesn't exist on any of the maps, going to the places he never even heard of, searching for an answer and his dreamgirl."]
#
# Movie: Once Upon a Time... in Hollywood
# Mentioned Sentences: []
#
# Movie: Nelyubov
# Mentioned Sentences: []
#
# Movie: The Florida Project
# Mentioned Sentences: []
#
# Movie: Just Mercy
# Mentioned Sentences: []
#
# Movie: Gifted
# Mentioned Sentences: []
#
# Movie: The Peanut Butter Falcon
# Mentioned Sentences: []
#
# Movie: Victoria
# Mentioned Sentences: ['The people of a small village in Victorian India stake their future on a game of cricket against their ruthless British rulers.', 'A Victorian surgeon rescues a heavily disfigured man who is mistreated while scraping a living as a side-show freak. Behind his monstrous façade, there is revealed a person of kindness, intelligence and sophistication.']
#
# Movie: Mustang
# Mentioned Sentences: []
#
# Movie: Guardians of the Galaxy Vol. 2
# Mentioned Sentences: []
#
# Movie: Baby Driver
# Mentioned Sentences: []
#
# Movie: Only the Brave
# Mentioned Sentences: []
#
# Movie: Bridge of Spies
# Mentioned Sentences: []
#
# Movie: Incredibles 2
# Mentioned Sentences: []
#
# Movie: Moana
# Mentioned Sentences: ["In Ancient Polynesia, when a terrible curse incurred by the Demigod Maui reaches Moana's island, she answers the Ocean's call to seek out the Demigod to set things right."]
#
# Movie: Sicario
# Mentioned Sentences: []
#
# Movie: Creed
# Mentioned Sentences: ['The former World Heavyweight Champion Rocky Balboa serves as a trainer and mentor to Adonis Johnson, the son of his late friend and former rival Apollo Creed.']
#
# Movie: Leviafan
# Mentioned Sentences: []
#
# Movie: Hell or High Water
# Mentioned Sentences: []
#
# Movie: Philomena
# Mentioned Sentences: []
#
# Movie: Dawn of the Planet of the Apes
# Mentioned Sentences: []
#
# Movie: El cuerpo
# Mentioned Sentences: []
#
# Movie: Serbuan maut
# Mentioned Sentences: []
#
# Movie: End of Watch
# Mentioned Sentences: []
#
# Movie: Kari-gurashi no Arietti
# Mentioned Sentences: []
#
# Movie: A Star Is Born
# Mentioned Sentences: []
#
# Movie: True Grit
# Mentioned Sentences: []
#
# Movie: Hævnen
# Mentioned Sentences: []
#
# Movie: Despicable Me
# Mentioned Sentences: []
#
# Movie: 50/50
# Mentioned Sentences: []
#
# Movie: Kick-Ass
# Mentioned Sentences: []
#
# Movie: Celda 211
# Mentioned Sentences: []
#
# Movie: Moneyball
# Mentioned Sentences: []
#
# Movie: La piel que habito
# Mentioned Sentences: []
#
# Movie: Zombieland
# Mentioned Sentences: []
#
# Movie: Die Welle
# Mentioned Sentences: []
#
# Movie: Sherlock Holmes
# Mentioned Sentences: ['Detective Sherlock Holmes and his stalwart partner Watson engage in a battle of wits and brawn with a nemesis whose plot is a threat to all of England.']
#
# Movie: The Blind Side
# Mentioned Sentences: []
#
# Movie: The Visitor
# Mentioned Sentences: []
#
# Movie: Seven Pounds
# Mentioned Sentences: []
#
# Movie: Eastern Promises
# Mentioned Sentences: []
#
# Movie: Stardust
# Mentioned Sentences: []
#
# Movie: The Secret of Kells
# Mentioned Sentences: []
#
# Movie: Inside Man
# Mentioned Sentences: []
#
# Movie: Gone Baby Gone
# Mentioned Sentences: []
#
# Movie: La Vie En Rose
# Mentioned Sentences: []
#
# Movie: Huo Yuan Jia
# Mentioned Sentences: []
#
# Movie: The Illusionist
# Mentioned Sentences: []
#
# Movie: Dead Man's Shoes
# Mentioned Sentences: []
#
# Movie: Harry Potter and the Half-Blood Prince
# Mentioned Sentences: []
#
# Movie: 300
# Mentioned Sentences: ['King Leonidas of Sparta and a force of 300 men fight the Persians at Thermopylae in 480 B.C.']
#
# Movie: Match Point
# Mentioned Sentences: []
#
# Movie: Watchmen
# Mentioned Sentences: []
#
# Movie: Lord of War
# Mentioned Sentences: []
#
# Movie: Saw
# Mentioned Sentences: ['A Polish Jewish musician struggles to survive the destruction of the Warsaw ghetto of World War II.']
#
# Movie: Synecdoche, New York
# Mentioned Sentences: []
#
# Movie: Mysterious Skin
# Mentioned Sentences: []
#
# Movie: Jeux d'enfants
# Mentioned Sentences: []
#
# Movie: Un long dimanche de fiançailles
# Mentioned Sentences: []
#
# Movie: The Station Agent
# Mentioned Sentences: []
#
# Movie: 21 Grams
# Mentioned Sentences: []
#
# Movie: Boksuneun naui geot
# Mentioned Sentences: []
#
# Movie: Finding Neverland
# Mentioned Sentences: []
#
# Movie: 25th Hour
# Mentioned Sentences: []
#
# Movie: The Butterfly Effect
# Mentioned Sentences: []
#
# Movie: 28 Days Later...
# Mentioned Sentences: []
#
# Movie: Batoru rowaiaru
# Mentioned Sentences: []
#
# Movie: The Royal Tenenbaums
# Mentioned Sentences: []
#
# Movie: Y tu mamá también
# Mentioned Sentences: []
#
# Movie: Harry Potter and the Sorcerer's Stone
# Mentioned Sentences: []
#
# Movie: The Others
# Mentioned Sentences: []
#
# Movie: Blow
# Mentioned Sentences: ['An honest New York cop named Frank Serpico blows the whistle on rampant corruption in the force only to have his comrades turn against him.']
#
# Movie: Enemy at the Gates
# Mentioned Sentences: []
#
# Movie: Minority Report
# Mentioned Sentences: []
#
# Movie: The Hurricane
# Mentioned Sentences: []
#
# Movie: American Psycho
# Mentioned Sentences: []
#
# Movie: Lola rennt
# Mentioned Sentences: []
#
# Movie: The Thin Red Line
# Mentioned Sentences: []
#
# Movie: Mulan
# Mentioned Sentences: ["The brash James T. Kirk tries to live up to his father's legacy with Mr. Spock keeping him in check as a vengeful Romulan from the future creates black holes to destroy the Federation one planet at a time."]
#
# Movie: Fear and Loathing in Las Vegas
# Mentioned Sentences: []
#
# Movie: Funny Games
# Mentioned Sentences: []
#
# Movie: Dark City
# Mentioned Sentences: []
#
# Movie: Sleepers
# Mentioned Sentences: []
#
# Movie: Lost Highway
# Mentioned Sentences: []
#
# Movie: Sense and Sensibility
# Mentioned Sentences: []
#
# Movie: Die Hard: With a Vengeance
# Mentioned Sentences: []
#
# Movie: Dead Man
# Mentioned Sentences: []
#
# Movie: The Bridges of Madison County
# Mentioned Sentences: []
#
# Movie: Apollo 13
# Mentioned Sentences: ['NASA must devise a strategy to return Apollo 13 to Earth safely after the spacecraft undergoes massive internal damage putting the lives of the three astronauts on board in jeopardy.']
#
# Movie: Trois couleurs: Blanc
# Mentioned Sentences: []
#
# Movie: Falling Down
# Mentioned Sentences: []
#
# Movie: Dazed and Confused
# Mentioned Sentences: []
#
# Movie: My Cousin Vinny
# Mentioned Sentences: []
#
# Movie: Omohide poro poro
# Mentioned Sentences: []
#
# Movie: Delicatessen
# Mentioned Sentences: []
#
# Movie: Home Alone
# Mentioned Sentences: ['An eight-year-old troublemaker must protect his house from a pair of burglars when he is accidentally left home alone by his family during Christmas vacation.']
#
# Movie: The Godfather: Part III
# Mentioned Sentences: []
#
# Movie: When Harry Met Sally...
# Mentioned Sentences: []
#
# Movie: The Little Mermaid
# Mentioned Sentences: []
#
# Movie: The Naked Gun: From the Files of Police Squad!
# Mentioned Sentences: []
#
# Movie: Planes, Trains & Automobiles
# Mentioned Sentences: []
#
# Movie: Lethal Weapon
# Mentioned Sentences: []
#
# Movie: Blood Simple
# Mentioned Sentences: []
#
# Movie: On Golden Pond
# Mentioned Sentences: []
#
# Movie: Mad Max 2
# Mentioned Sentences: []
#
# Movie: The Warriors
# Mentioned Sentences: ['In the near future, a charismatic leader summons the street gangs of New York City in a bid to take it over. When he is killed, The Warriors are falsely blamed and now must fight their way home while every other gang is hunting them down.']
#
# Movie: The Muppet Movie
# Mentioned Sentences: []
#
# Movie: Escape from Alcatraz
# Mentioned Sentences: []
#
# Movie: Watership Down
# Mentioned Sentences: []
#
# Movie: Midnight Express
# Mentioned Sentences: []
#
# Movie: Close Encounters of the Third Kind
# Mentioned Sentences: []
#
# Movie: The Long Goodbye
# Mentioned Sentences: []
#
# Movie: Giù la testa
# Mentioned Sentences: []
#
# Movie: Kelly's Heroes
# Mentioned Sentences: []
#
# Movie: The Jungle Book
# Mentioned Sentences: []
#
# Movie: Blowup
# Mentioned Sentences: []
#
# Movie: A Hard Day's Night
# Mentioned Sentences: []
#
# Movie: Breakfast at Tiffany's
# Mentioned Sentences: []
#
# Movie: Giant
# Mentioned Sentences: ['A young boy befriends a giant robot from outer space that a paranoid government agent wants to destroy.', 'On a faraway planet where blue giants rule, oppressed humanoids rebel against their machine-like leaders.']
#
# Movie: From Here to Eternity
# Mentioned Sentences: []
#
# Movie: Lifeboat
# Mentioned Sentences: ['Several survivors of a torpedoed merchant ship in World War II find themselves in the same lifeboat with one of the crew members of the U-boat that sank their ship.']
#
# Movie: The 39 Steps
# Mentioned Sentences: []

# %%
# encode snetences with BERT
def encode_sentence(sentences, tokenizer, model):
    inputs = tokenizer(sentences, return_tensors='pt', padding=True, turncation=True)
    with torch.no_grad():
        outputs = model(**inputs)
    sentences_embeddings = outputs.last_hidden_state[:, 0, :]
    return sentences_embeddings

encoded_sentences = encode_sentence(mention_sentences, tokenizer, model)

# %%
# average the embeddings
def average_embeddings(embeddings):
    return torch.mean(embeddings, dim=0)

average_embedding = average_embeddings(encoded_sentences)
