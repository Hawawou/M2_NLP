# %% [markdown]
# # Introduction to Automatic Speech Recognition
#
# **Name**:
#
# This lab is an introduction to automatic speech recognition (ASR). In a nutshell, the ASR process consists of the following blocks:
#
# 1. **Feature extraction**: The audio waveform is preprocessed into normalized features such as spectrogram or MFCCs.
# 2. **Acoustic model**: The features are transformed into high-dimensional embeddings via a deep neural network (here: [wav2vec2](https://arxiv.org/pdf/2006.11477)), and then a classifier is applied to predict the class of each token (=character) at each time step.
# 3. **Decoding**: A transcript is generated from the sequence of class probabilities, either using a language model or not.
#
# <center><a href="https://developer.nvidia.com/blog/how-to-build-domain-specific-automatic-speech-recognition-models-on-gpus/">
#     <img src="https://developer-blogs.nvidia.com/wp-content/uploads/2019/12/ASR-Pipeline-1.png" width="600"></a></center>
#
# In this lab, we experiment with ASR using pretrained acoustic models (which include feature extraction for simplicity). We provide a dataset of real-life speech audio (with trancription) in order to study the influence of several factors onto the performance of a modern ASR system. We focus on the usage of the acoustic model, thus we use a simple decoder with no language model (this will be the topic of the next lab).
#
# This series of lab relies on [torchaudio](https://pytorch.org/audio/stable/index.html), which is a pytorch-based librairy for audio/signal processing. More specifically, this lab is based on this [tutorial](https://pytorch.org/audio/stable/tutorials/speech_recognition_pipeline_tutorial.html#sphx-glr-tutorials-speech-recognition-pipeline-tutorial-py), which you are encouraged to check.

# %%
import torch
import torchaudio
import IPython
import os
import fnmatch
import matplotlib.pyplot as plt
torch.random.manual_seed(0)

MAX_FILES = 100 # lower this number for processing a subset of the dataset

# %% [markdown]
# ## Load and display an audio example
#
# Let us first load an audio file, listen to it using an audio reader, and plot the waveform.

# %%
# Dataset path (audio and transcripts)
data_speech_dir = "asr-dataset/speech/"
data_transc_dir = "/asr-dataset/transcription/"

# %%
# Example file
audio_file = 'asr-dataset/speech/61-70968-0001.wav'
waveform, sr = torchaudio.load(audio_file, channels_first=True)
IPython.display.Audio(data=waveform, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Plot the speech signal waveform
plt.figure()
xt = torch.arange(waveform.size(1)) / sr
plt.plot(xt, waveform.T)
plt.yticks([])
plt.xlabel("Time (s)")
plt.show()

# %% [markdown]
# ## Acoustic model
#
# Let us create an acoustic model that performs feature extraction and classification. In this lab, we use [wav2vec2](https://arxiv.org/pdf/2006.11477), a self-supervised audio model that produces state-of-the-art results for many audio tasks (including ASR).
#
# For convenience, both the model definition and pretrained wav2vec2 weights can be directly loaded using torchaudio, which includes two types of weights:
# - The pretrained weights [without fine-tuning](https://pytorch.org/audio/stable/pipelines.html#id3), that can be fine-tuned for any other downstream tasks (e.g., emotion recognition or language detection).
# - The pretrained weights that are [fine-tuned for the ASR task](https://pytorch.org/audio/stable/pipelines.html#id36), using an extra classification layer after feature extraction with wav2vec2.
#
# In this series of lab, we use the latter. Below we provide the code for constructing a model and fetching the pretrained weights along with the classification labels. Here we use the `WAV2VEC2_ASR_BASE_100H` model. As the name indicates, it is a basic wav2vec2 architecture that is fine-tuned for ASR using 100 hours of the Librispeech dataset (containing both speech and transcriptions). Other models can be fetched using torchaudio (see the list [here](https://pytorch.org/audio/stable/pipelines.html#id36)).

# %%
# Load the acoustic model
model_name = 'WAV2VEC2_ASR_BASE_100H'
bundle = getattr(torchaudio.pipelines, model_name)
acoustic_model = bundle.get_model()

# %%
# Display the details of the model's architecture (more info on this in the Neural Network labs!)
print(acoustic_model)
# Out:
# Wav2Vec2Model(
#   (feature_extractor): FeatureExtractor(
#     (conv_layers): ModuleList(
#       (0): ConvLayerBlock(
#         (layer_norm): GroupNorm(512, 512, eps=1e-05, affine=True)
#         (conv): Conv1d(1, 512, kernel_size=(10,), stride=(5,), bias=False)
#       )
#       (1-4): 4 x ConvLayerBlock(
#         (conv): Conv1d(512, 512, kernel_size=(3,), stride=(2,), bias=False)
#       )
#       (5-6): 2 x ConvLayerBlock(
#         (conv): Conv1d(512, 512, kernel_size=(2,), stride=(2,), bias=False)
#       )
#     )
#   )
#   (encoder): Encoder(
#     (feature_projection): FeatureProjection(
#       (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (projection): Linear(in_features=512, out_features=768, bias=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (pos_conv_embed): ConvolutionalPositionalEmbedding(
#         (conv): ParametrizedConv1d(
#           768, 768, kernel_size=(128,), stride=(1,), padding=(64,), groups=16
#           (parametrizations): ModuleDict(
#             (weight): ParametrizationList(
#               (0): _WeightNorm()
#             )
#           )
#         )
#       )
#       (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (layers): ModuleList(
#         (0-11): 12 x EncoderLayer(
#           (attention): SelfAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): FeedForward(
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (aux): Linear(in_features=768, out_features=29, bias=True)
# )

# %%
# Get and display the classification labels
labels = bundle.get_labels()
print('Labels:', labels)
# Out:
# Labels: ('-', '|', 'E', 'T', 'A', 'O', 'N', 'I', 'H', 'S', 'R', 'D', 'L', 'U', 'M', 'W', 'C', 'F', 'G', 'Y', 'P', 'B', 'V', 'K', "'", 'X', 'J', 'Q', 'Z')

# %% [markdown]
# We can now apply the acoustic model to the example audio signal wa have loaded above. We can either compute the acoustic features or predicting the labels after the classification layer (also called the *emission* matrix/tensor):
# - `features` is a list of tensors, where each tensor is the output of a transformer layer from the wav2vec2 model.

# %%
with torch.inference_mode():
    features, _ = acoustic_model.extract_features(waveform)

print(f"Number of transformer layers: {len(features)}")
print(features[0].shape)
# Out:
# Number of transformer layers: 12
# torch.Size([1, 180, 768])

# %% [markdown]
# - `emission` is a tensor of size `[1, time steps, number of classes]` corresponding to the output of the classification layer (`1` corresponds to the batch size). Note that it is in the form of logits, not probabilities (thus it is not normalized in $[0, 1]$).

# %%
with torch.inference_mode():
    emission, _ = acoustic_model(waveform)

print(emission.shape)
# Out:
# torch.Size([1, 180, 29])

# %%
# Vizualize the result of the classification
plt.figure()
plt.imshow(emission[0].cpu().T)
plt.title("Classification result")
plt.xlabel("Frame (time-axis)")
plt.ylabel("Class")
plt.tight_layout()
plt.show()

# %% [markdown]
# We can compute the most likely label at each time frame to get a first rough transcript estimate, as done below.

# %%
indices = torch.argmax(emission[0], dim=-1)  # take the most likely index at each time step
pred_labels = [labels[i] for i in indices] # transform each index into the corresponding label
print(pred_labels)
# Out:
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', 'G', '-', '-', '-', '-', '-', 'I', '-', '-', '-', 'V', '-', 'E', 'E', '-', '|', '|', '-', '-', 'N', 'N', '-', '-', '-', 'O', '-', '-', 'T', '-', '|', '|', '-', '-', 'S', '-', '-', '-', 'O', 'O', '-', '|', '|', '|', '-', '-', '-', '-', 'E', 'E', 'A', 'A', 'A', 'R', 'N', 'N', '-', '-', 'E', '-', 'S', 'S', '-', 'T', 'T', '|', '|', '|', 'A', '-', '|', '|', '-', '-', 'M', '-', '-', '-', '-', '-', '-', 'I', 'I', '-', 'N', '-', 'D', '-', '|', '-', 'T', '-', 'O', '|', '|', 'T', 'H', 'H', 'E', 'E', 'S', 'S', 'E', 'E', '|', '|', '-', '-', '-', 'M', '-', '-', 'U', 'M', 'M', 'M', 'M', '-', 'O', 'R', 'R', 'R', '-', '-', '-', 'I', 'I', 'E', 'E', '-', '-', 'S', '-', '|', '|', '-', '-', '-', '-', '-', 'C', 'H', '-', '-', '-', '-', '-', '-', '-', 'I', 'I', '-', 'L', 'L', 'L', 'L', '-', 'D', '-', '-', '|', '-', '-', '-']

# %% [markdown]
# Note that there are many blank labels `'-'`, as well as duplicates. This is why some further postprocessing / decoding is needed.
#
# ## Decoding
#
# From the emission tensor, which is the sequence of probabilities (or logits) for each class / token, we now want to generate a transcript (or *hypothesis*). This process is called *decoding*. Decoding can be complex because it implies accounting for the context in order to avoid duplicates, assembling characters into words, identifying precise word start / end, and building sequences of words that make sense given some underlying language model.
#
# Such refined decoding techniques involve using external ressources such as lexicon and language models. In this lab however, we rely on a naive approach called a *greedy* decoder, which does not depend on such components. The context information is not used (= we pick the best hypothesis at each time step), and only one transcript is generated by applying some basic post-processing (removing blank tokens and duplicates).

# %%
class GreedyDecoder(torch.nn.Module):
    def __init__(self, labels, blank_token_indx=0):
        super().__init__()
        self.labels = labels
        self.blank_token_indx = blank_token_indx

    def forward(self, emission):
        """Given a sequence emission over labels, decode the transcript
        Args:
          emission (Tensor): Logit tensors. Shape `[1, num_seq, num_label]`.
        Returns:
          transcript (List of strings): The resulting transcript
        """
        emission = emission[0] # take the first element in the batch (only one)
        indices = torch.argmax(emission, dim=-1)  # take the most likely index at each time step
        indices = torch.unique_consecutive(indices, dim=-1) # remove duplicates
        indices = [i for i in indices if i != self.blank_token_indx] # remove blank token
        transcript = "".join([self.labels[i] for i in indices]) # convert indices into tokens
        transcript = transcript.replace("|", " ").lower().split() # a bit of post-processing
        return transcript

# %%
# Instanciate the decoder, apply it, and display the result
decoder = GreedyDecoder(labels=labels)
est_transcript = decoder(emission)
print(est_transcript) #GIVE NOT SO EARNEST A MIND TO THESE MUMMERIES CHILD
# Out:
# ['give', 'not', 'so', 'earnest', 'a', 'mind', 'to', 'these', 'mumories', 'child']

# %% [markdown]
# ## Evaluation
#
# To evaluate the quality of the transcript above, we need to compare it to some reference. More precisely, we can compute the [word error rate](https://en.wikipedia.org/wiki/Word_error_rate) (WER) between the reference and estimated transcripts. The WER is a measure of speech recognition performance expressed in % (lower is better) based on the Levenshtein distance, which allows to account for the fact that the true and estimated transcripts might have different lengths; more info in the course.
#
# For the example we used until now, the true transcript is stored in the file `asr-dataset/transcription/61-70968-0001.txt` (note the file name is similar as the audio, except for the subfolder and extension).
#
# <span style="color:red"> **Exercise 1**</span>. Load the content of this file to get the true transcript, and preprocess it to the same format as the estimated transcript above (i.e., use the `.lower()` and `.split()` methods). Display the true transcript. Then, using the provided `get_wer` function, compute and display

# %%
with open('asr-dataset/transcription/61-70968-0001.txt', 'r') as f:
    true_transcript = f.readlines()
    true_transcript = true_transcript[0].strip().lower().split()
    print(true_transcript)
# Out:
# ['give', 'not', 'so', 'earnest', 'a', 'mind', 'to', 'these', 'mummeries', 'child']

# %%
def get_wer(true_transcript, est_transcript):
    wer = torchaudio.functional.edit_distance(true_transcript, est_transcript) / len(true_transcript)
    return wer

# %%
wer = get_wer(true_transcript, est_transcript)
print(wer)
# Out:
# 1.1

# %% [markdown]
# ## Process a folder
#
# <span style="color:red"> **Exercise 2**</span>. Process the entire dataset folder (=the 100 files) using the wav2vec2 acoustic model and the greedy decoder above, and compute and display the mean WER over the dataset.

# %%
# We provide a function below that returns the list of all files in a directory
def find_files(directory, pattern='*.wav'):
    """Recursively finds all files matching the pattern."""
    files = []
    for root, _, filenames in os.walk(directory):
        for filename in fnmatch.filter(filenames, pattern):
            files.append(filename)
    files = sorted(files)
    return files

# Get the list of audio files in the asr dataset
audio_files = find_files(data_speech_dir)
print(audio_files[:10])
# Out:
# ['121-121726-0002.wav', '121-121726-0004.wav', '121-121726-0005.wav', '121-121726-0006.wav', '121-121726-0008.wav', '121-121726-0011.wav', '121-121726-0012.wav', '121-121726-0013.wav', '121-121726-0014.wav', '121-123852-0001.wav']

# %%
from pathlib import Path

# data_transc_dir = "./asr-dataset/transcription/"
path = '/home/oumar/School/Speech/asr-dataset/transcription/'
transcripts = []
for filename in os.listdir(path):
    if filename.endswith('.txt'):
        file_path = os.path.join(path, filename)

        with open(file_path, 'r') as f:
            data = f.readlines()
            data = data[0].strip().lower().split()
            # print(data)
            transcripts.append(data)
print(transcripts)
# Out:
# [['he', 'began', 'a', 'confused', 'complaint', 'against', 'the', 'wizard', 'who', 'had', 'vanished', 'behind', 'the', 'curtain', 'on', 'the', 'left'], ['hedge', 'a', 'fence'], ['silence', 'you', 'knave', 'cried', 'montfichet'], ['she', 'has', 'been', 'dead', 'these', 'twenty', 'years'], ['but', 'was', 'that', 'all', 'her', 'reward', 'one', 'of', 'the', 'ladies', 'asked'], ['hose', "man's", 'excuse', 'for', 'wetting', 'the', 'walk'], ['if', 'for', 'a', 'whim', 'you', 'beggar', 'yourself', 'i', 'cannot', 'stay', 'you'], ['dismiss', 'your', 'squire', 'robin', 'and', 'bid', 'me', 'good', 'e', 'e', 'n'], ['oh', 'no', 'jasper', 'i', 'must', 'go', 'by', 'my', 'very', 'own', 'self'], ['master', 'monceux', 'the', 'sheriff', 'of', 'nottingham', 'was', 'mightily', 'put', 'about', 'when', 'told', 'of', 'the', 'rioting'], ['surely', 'we', 'can', 'submit', 'with', 'good', 'grace'], ['like', 'as', 'not', 'young', 'master', 'though', 'i', 'am', 'an', 'old', 'man'], ['robin', 'entered', 'the', 'hut', 'dragging', 'the', 'unwilling', 'esquire', 'after', 'him'], ['no', 'thanks', 'i', 'am', 'glad', 'to', 'give', 'you', 'such', 'easy', 'happiness'], ['come', 'to', 'me', 'men', 'here', 'here', 'he', 'raised', 'his', 'voice', 'still', 'louder'], ['he', 'is', 'my', 'esquire', 'excellency', 'returned', 'robin', 'with', 'dignity'], ['beg', 'me', 'a', 'room', 'of', 'the', 'sheriff', 'child', 'quickly'], ['the', 'wine', 'did', 'certainly', 'bring', 'back', 'the', 'color', 'to', 'the', "squire's", 'cheeks'], ['how', 'did', 'her', 'mother', 'ever', 'let', 'her', 'go'], ['from', 'the', 'blackness', 'behind', 'the', 'light', 'they', 'heard', 'a', 'voice', "warrenton's"], ['the', 'strollers', 'took', 'their', 'part', 'in', 'it', 'with', 'hearty', 'zest', 'now', 'that', 'they', 'had', 'some', 'chance', 'of', 'beating', 'off', 'their', 'foes'], ['it', 'will', 'not', 'be', 'safe', 'for', 'you', 'to', 'stay', 'here', 'now'], ['the', 'others', 'resented', 'postponement', 'but', 'it', 'was', 'just', 'his', 'scruples', 'that', 'charmed', 'me'], ['there', 'there', 'he', 'said', 'soothingly', 'patting', 'her', 'brown', 'fuzzy', 'head'], ['the', "story's", 'written'], ['now', "you'll", 'stay', 'cried', 'van', 'say', 'polly', "won't", 'you'], ['nottingham', 'castle', 'was', 'reached', 'and', 'admittance', 'was', 'demanded'], ['missus', 'griffin', 'however', 'expressed', 'the', 'need', 'for', 'a', 'little', 'more', 'light'], ['hypocrite', 'a', 'horse', 'dealer'], ['i', "don't", 'anticipate'], ['give', 'not', 'so', 'earnest', 'a', 'mind', 'to', 'these', 'mummeries', 'child'], ['hussy', 'woman', 'and', 'bond', 'tie'], ['he', 'hung', 'fire', 'again', 'a', "woman's"], ['before', 'them', 'fled', 'the', 'stroller', 'and', 'his', 'three', 'sons', 'capless', 'and', 'terrified'], ['but', 'then', 'the', 'picture', 'was', 'gone', 'as', 'quickly', 'as', 'it', 'came'], ['it', "wasn't", 'simply', 'that', 'she', 'said', 'so', 'but', 'that', 'i', 'knew', 'she', "hadn't", 'i', 'was', 'sure', 'i', 'could', 'see'], ['george', 'montfichet', 'will', 'never', 'forget', 'this', 'day'], ['angor', 'pain', 'painful', 'to', 'hear'], ['most', 'of', 'all', 'robin', 'thought', 'of', 'his', 'father', 'what', 'would', 'he', 'counsel'], ['husband', 'the', 'next', 'thing', 'to', 'a', 'wife'], ['he', 'was', 'in', 'deep', 'converse', 'with', 'the', 'clerk', 'and', 'entered', 'the', 'hall', 'holding', 'him', 'by', 'the', 'arm'], ['now', 'to', 'bed', 'boy'], ['she', 'sent', 'me', 'the', 'pages', 'in', 'question', 'before', 'she', 'died'], ["don't", 'mind', 'it', 'polly', 'whispered', 'jasper', "twasn't", 'her', 'fault'], ['they', 'regained', 'their', 'apartment', 'apparently', 'without', 'disturbing', 'the', 'household', 'of', 'gamewell'], ['yet', 'he', 'will', 'teach', 'you', 'a', 'few', 'tricks', 'when', 'morning', 'is', 'come'], ['pray', 'follow', 'us', 'with', 'mine', 'and', 'my', 'lord', "sheriff's", 'men'], ['if', 'she', 'could', 'only', 'see', 'phronsie', 'for', 'just', 'one', 'moment'], ['so', 'i', 'd ...

# %%
# acoustic model on all the files 
for i, audio_file in enumerate(audio_files):
    waveform, sr = torchaudio.load(os.path.join(data_speech_dir, audio_file), channels_first=True)
    with torch.inference_mode():
        emission, _ = acoustic_model(waveform)
    est_transcript = decoder(emission)

    print(est_transcript)
# Out:
# ['angor', 'hane', 'painful', 'to', 'hear']
# ['heaven', 'a', 'good', 'place', 'to', 'be', 'raised', 'to']
# ['hedge', 'offence']
# ['heredity', 'the', 'cause', 'of', 'all', 'our', 'faults']
# ['hos', "man's", 'excuse', 'for', 'wetting', 'the', 'walk']
# ['husband', 'the', 'next', 'thing', 'to', 'a', 'wife']
# ['hussy', 'woman', 'and', 'bond', 'tie']
# ['tied', 'to', 'a', 'woman']
# ['hypocrit', 'a', 'horse', 'dealer']
# ['i', 'me']
# ['the', 'story', 'is', 'written']
# ['the', 'others', 'resented', 'posponment', 'but', 'it', 'was', 'just', 'his', 'scruples', 'that', 'charmed', 'me']
# ['he', 'hung', 'fire', 'again', 'o', "woman's"]
# ['she', 'has', 'been', 'dead', 'these', 'twenty', 'years']
# ['she', 'sent', 'me', 'the', 'pages', 'ind', 'questiond', 'before', 'she', 'died']
# ['it', "wasn't", 'simply', 'that', 'she', 'said', 'so', 'but', 'that', 'i', 'knew', 'she', "hadn't", 'i', 'was', 'sure', 'i', 'could', 'see']
# ['you', 'are', 'accute']
# ['he', 'quitted', 'the', 'fire', 'and', 'dropped', 'back', 'into', 'his', 'chair']
# ['probably', 'not', 'till', 'the', 'second', 'post']
# ['it', 'was', 'almost', 'the', 'tone', 'of', 'hope', 'everybody', 'will', 'stay']
# ['cried', 'the', 'ladies', 'whose', 'departure', 'had', 'been', 'fixed']
# ['missus', 'griffin', 'however', 'expressed', 'the', 'need', 'for', 'a', 'little', 'more', 'light']
# ["won't", 'you', 'tell', 'douglas']
# ['i', "don't", 'anticipate']
# ['yes', 'but', "that's", 'just', 'the', 'beauty', 'of', 'her', 'passion']
# ['it', 'was', 'the', 'beauty', 'of', 'it']
# ['but', 'was', 'that', 'all', 'her', 'reward', 'one', 'of', 'the', 'ladies', 'asked']
# ['if', 'she', 'could', 'only', 'see', 'phronsie', 'for', 'just', 'one', 'moment']
# ['asked', 'phronsie', 'with', 'her', 'little', 'face', 'close', 'to', "polly's", 'own']
# ['now', "you'll", 'stay', 'cried', 'anne', 'say', 'polly', "won't", 'you']
# ['there', 'there', 'he', 'said', 'soothingly', 'patting', 'her', 'brown', 'fuzsy', 'head']
# ['oh', 'no', 'japser', 'i', 'must', 'go', 'by', 'my', 'very', 'own', 'self']
# ["don't", 'mind', 'it', 'polly', 'whispered', 'jasper', "twasn't", 'her', 'fault']
# ['how', 'did', 'her', 'mother', 'ever', 'let', 'her', 'go']
# ['she', 'asked', 'impulsively', 'i', "didn't", 'believe', 'you', 'could', 'persuade', 'her', 'father']
# ['at', 'last', 'he', 'came', 'out', 'of', 'them', 'and', 'wiped', 'his', 'face', 'vigorously']
# ['he', 'began', 'a', 'confused', 'complaint', 'against', 'the', 'wizard', 'who', 'had', 'vanished', 'behind', 'the', 'curtain', 'on', 'the', 'left']
# ['give', 'not', 'so', 'earnest', 'a', 'mind', 'to', 'these', 'mumories', 'child']
# ['a', 'golden', 'fortune', 'in', 'a', 'happy', 'life']
# ['he', 'was', 'like', 'unto', 'my', 'father', 'in', 'a', 'way', 'and', 'yet', 'was', 'not', 'my', 'father']
# ['also', 'there', 'was', 'a', 'strippling', 'page', 'who', 'turned', 'into', 'a', 'maid']
# ['but', 'then', 'the', 'picture', 'was', 'gone', 'as', 'quickly', 'as', 'it', 'came']
# ['sister', 'nell', 'do', 'you', 'hear', 'these', 'marvels']
# ['take', 'your', 'place', 'and', 'let', 'us', 'see', 'what', 'the', 'crystel', 'can', 'show', 'to', 'you']
# ['like', 'is', 'not', 'young', 'master', 'though', 'i', 'am', 'an', 'old', 'man']
# ['cries', 'of', 'a', 'nottingham', 'a', 'nottingham']
# ['before', 'them', 'fled', 'the', 'stroller', 'and', 'his', 'three', 'sons', 'capitlas', 'and', 'terrified']
# ['and', 'then', 'they', 'became', 'vexed', 'and', 'would', 'have', 'snatched', 'your', 'purse', 'from', 'us']
# ['so', 'i', 'did', 'push', 'this', 'fellow']
# ['surely', 'we', 'can', 'submit', 'with', 'good', 'grace']
# ['tis', 'fine', 'for', 'you', 'to', 'talk', 'old', 'man', 'answered', 'the', 'lean', 'sulen', 'apprentice']
# ['come', 'to', 'me', 'men', 'her', 'her', 'he', 'raised', 'his', 'voice', 'still', 'louder']
# ['the', 'strollers', 'took', 'their', 'part', 'in', 'it', 'with', 'hearty', 'zess', 'now', 'that', 'they', 'had', 'some', 'chance', 'of', 'beating', 'off', 'their', 'fos']
# ['the', 'squire', 'helped', 'to', 'thrust', 'them', 'all', 'in', 'and', 'entered', 'swiftly', 'himself']
# ['silence', 'you', 'nave', 'cried', 'mont', 'fichet']
# ['he', 'felt', 'for', 'and', 'found', 'the', "wizard's", 'black', 'cloth', 'the', 'squire', 'was', 'quite', 'out', 'of', 'breath']
# ['a', 'mont', 'fichet', 'a', 'mont', 'fichet', 'game', 'well', 'to', 'the', 'rescue']
# ['george', 'montfijet', 'will', 'never', 'forget', 'this', 'day']
# ['what', 'is', 'your', 'name', 'lording', 'asked', 'the', 'little', 'stroller', 'presently']
# ['robin', 'fits', 'uth']
# ['and', 'mine', 'is', 'will', 'stutley', 'shall', 'we', 'be', 'comrades']
# ['right', 'willingly', 'for', 'between', 'us', 'we', 'have', 'won', 'the', 'battle', 'answered', 'robin']
# ['mont', 'ficet', 'called', 'out', 'for', 'robin', 'to', 'give', 'him', 'an', 'arm']
# ['it', 'will', 'not', 'be', 'safe', 'for', 'you', 'to', 'stay', 'here', 'now']
# ['pray', 'follow', 'us', 'with', 'mine', 'and', 'my', 'lord', "sheriff's", 'men']
# ['naudingham', 'castle', 'was', 'reached', 'an', 'admittance', 'was', 'demanded']
# ['master', 'monseu', 'the', 'sheriff', 'of', 'noddingham', 'was', 'mightily', 'put', 'about', 'when', 'told', 'of', 'the', 'rieting']
# ['and', 'henry', 'might', 'return', 'to', 'england', 'at', 'any', 'moment']
# ['beg', 'me', 'a', 'room', 'of', 'the', 'sheriff', 'child', 'quickly']
# ['but', 'who', 'is', 'this', 'fellow', 'plucking', 'at', 'your', 'steeve']
# ['he', 'is', 'my', 'esquire', 'excellency', 'returned', 'robin', 'with', 'dignity']
# ['robin', 'was', 'glad', 'when', 'at', 'length', 'they', 'were', 'left', 'to', 'their', 'own', 'devices']
# ['the', 'wine', 'did', 'certainly', 'bring', 'back', 'the', 'color', 'to', 'the', "squire's", 'cheeks']
# ['will', 'you', 'forgive', 'me', 'now']
# ['it', 'will', 'be', 'no', 'disappointment', 'to', 'me']
# ['no', 'thanks', 'i', 'am', 'glad', 'to', 'give', 'you', 'such', 'easy', 'happiness']
# ['i', 'and', 'show', 'you', 'some', 'pretty', 'tricks']
# ['most', 'of', 'all', 'robin', 'thought', 'of', 'his', 'father', 'what', 'would', 'he', 'councel']
# ['if', 'for', 'a', 'whim', 'you', 'beggar', 'yourself', 'i', 'cannot', 'stay', 'you']
# ['the', 'lad', 'had', 'checked', 'him', 'then']
# ['never', 'that', 'sir', 'he', 'had', 'said']
# ['he', 'was', 'in', 'deep', 'converse', 'with', 'the', 'clerk', 'and', 'entered', 'the', 'hall', 'holding', 'him', 'by', 'the', 'arm']
# ['now', 'to', 'bed', 'boy']
# ['tis', 'late', 'and', 'i', 'go', 'myself', 'within', 'a', 'short', 'space']
# ['dismiss', 'your', 'squire', 'robin', 'and', 'bid', 'me', 'good', 'etin']
# ['yet', 'he', 'will', 'teach', 'you', 'a', 'few', 'tricks', 'when', 'morning', 'is', 'come']
# ['there', 'was', 'no', 'chance', 'to', 'alter', 'his', 'sleeping', 'room', 'ti', 'one', 'nearer', 'to', "gamewell's", 'chamber']
# ['presently', 'he', 'crossed', 'the', 'floor', 'of', 'his', 'room', 'with', 'decided', 'step']
# ['we', 'will', 'go', 'out', 'together', 'to', 'the', 'bower', 'there', 'is', 'a', 'way', 'down', 'to', 'the', 'court', 'from', 'my', 'window']
# ['rest', 'and', 'be', 'still', 'until', 'i', 'warn', 'you']
# ['the', 'hours', 'passed', 'wearily', 'by', 'and', 'movement', 'could', 'yet', 'be', 'heard', 'about', 'the', 'hall']
# ['at', 'last', 'all', 'was', 'quiet', 'and', 'black', 'and', 'the', 'courtyard', 'of', 'gamewell']
# ['robin', 'entered', 'the', 'hut', 'dragging', 'the', 'unwilling', 'esquire', 'after', 'him']
# ['be', 'not', 'so', 'foolish', 'friend', 'said', "fitt's", 'ooth', 'crossly']
# ['from', 'the', 'blackness', 'behind', 'the', 'light', 'they', 'heard', 'a', 'voice', 'warrantons']
# ['save', 'me', 'masters', 'but', 'you', 'startled', 'me', 'rarely']
# ['inquired', 'robin', 'with', 'his', 'suspicions', 'still', 'upon', 'him']
# ['truly', 'such', 'a', 'horse', 'would', 'be', 'worth', 'much', 'in', 'notting', 'him', 'fair']
# ['naay', 'nay', 'lording', 'answered', 'warrinton', 'with', 'a', 'half', 'laugh']
# ['they', 'regained', 'their', 'apartment', 'apparently', 'without', 'disturbing', 'the', 'household', 'of', 'ganwell']

# %% [markdown]
# ## Influence of the noise
#
# ASR systems are expected to be sensitive to the noise: while a model might work well on a clean recording, its performance will drop in real-life conditions where speech is contaminated with noise. We can simulate such a scenario by adding white noise to our speech waveforms.
#
# The amount of noise is controlled by the *signal-to-noise ratio* (SNR), expressed in dB. The lower the SNR, the noisier the mixture: a clean speech signal corresponds to SNR=+$\infty$, while a pure noise signal corresponds to SNR=-$\infty$.

# %%
# The functions below allow to generate white noise, and add it to the clean speech at a certain SNR level

def adjust_noise_snr(
    speech,
    noise,
    snr_dB,
    silence_threshold=0.01,
):

    # Filter out silence from speech signal
    speech_wo_silence = speech[torch.abs(speech) > silence_threshold]

    # Calculate the total energy of the speech and noise signals
    speech_power = torch.sum(torch.square(speech_wo_silence))
    noise_power = torch.sum(torch.square(noise))

    # Compute gain factor to achieve desired SNR
    gain_factor = torch.sqrt((speech_power / noise_power) * 10 ** (-snr_dB / 10))

    # Scale the noise accordingly
    scaled_noise = gain_factor * noise

    return scaled_noise


def add_noise(speech, snr_dB=0):
    # Generate random white noise
    noise = torch.randn_like(speech)
    # Adjust noise level
    noise = adjust_noise_snr(speech, noise, snr_dB)
    # Add the noise to the clean speech
    speech_noisy = speech + noise
    return speech_noisy, noise

# %%
# Add noise to the original audio signal at SNR = 0 dB
speech_noisy_0dB, noise_OdB = add_noise(waveform, snr_dB=0)
IPython.display.Audio(data=speech_noisy_0dB, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Add noise to the original audio signal at SNR = 5 dB
speech_noisy_5dB, noise_5dB = add_noise(waveform, snr_dB=5)
IPython.display.Audio(data=speech_noisy_5dB, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Display the noisy signals (vs. the clean one)
plt.figure()
xt = torch.arange(waveform.size(1)) / sr
plt.plot(xt, speech_noisy_0dB.T, label='noisy, SNR=0 dB')
plt.plot(xt, speech_noisy_5dB.T, label='noisy, SNR=5 dB')
plt.plot(xt, waveform.T, label='clean')
plt.yticks([])
plt.xlabel("Time (s)")
plt.legend()
plt.show()

# %% [markdown]
# <span style="color:red"> **Exercise 3**</span>. For each SNR $\in [-5, 0, 5, 10]$ dB, add noise to the files in the dataset, perform ASR and compute/display the mean WER. Comment.

# %%
def asr_snr(snr):
    all_transcripts = [] 

    for i, audio_file in enumerate(audio_files):
        # Load audio file
        waveform, sr = torchaudio.load(os.path.join(data_speech_dir, audio_file), channels_first=True)
        
        # Add noise
        speech_noisy, noise = add_noise(waveform, snr_dB=snr)

        # Run inference
        with torch.inference_mode():
            emission, _ = acoustic_model(speech_noisy)

        # Decode the emission to get the transcript
        est_transcript = decoder(emission)
        
        # Append transcript to list
        all_transcripts.append(est_transcript)
    
    return all_transcripts

# %%
# snr = -5
print(asr_snr(-5))
# Out:
# [['ang', 'vav', 'vai', 'edar'], ['heaven', 'i', 'go', 'i', 'e', 'lat'], ['head', 'tut', 'te'], ['e', 'regity', 'tii', 'at', 'allo', 'ta'], ['nat', 'i', 'wi', 'lik', 'dol'], ['i', 'ti', 'venet', 'thik', 'yo', 'gie'], ['atey', 'women', 'and', 'a', 'i'], ['i', 'a', 'i'], ['if', 'a', 'tir', 'u', 'dealer'], ['i', 'b'], ['the', 'stoys', 'tite'], ['the', 'aters', 'itafot', 'but', 'it', 'i', 'e', 'ot'], ['e', 'i', 'di', 'agan', 'o', 'im'], ['i', 'it', 'te', 'deadi', 'i', 'de'], ['if', 'tat', 'ti', 'i', 'ee', 'te', 'te', 'lo', 'o', 'he', 'di'], ['e', 'eeiee'], ['hea'], ['eculd', 'if', 'i', 'i', 'drop', 'back', 'dan'], ['owobly', 'not', 'eefected', 'e'], ['i', 'wa', 'al', 'bo', 'ooeverybody', 'ba', 'ta'], ['by', 'the', 'ladyy', 'yo', 'theparte', 'oe', 'tit'], ['ibi', 'atat', 'at', 'e', 'bae', 'ly', 'life'], ['efo', 'tae'], ['i', 'doubt', 'hav', 'i'], ['he', 'lik', 'at', 'ca', 'tafetyof', 'otee'], ['god', 'it', 'i', 'i'], ['bu', 'wit', 'tat', 'da', 'we', 'we', 'al', 'wut', 'i', 'e', 'late', 'do'], ['if', 'be', 'tad', 'only', 'e', 'ti', 'e', 'a', 'ti', 'ti', 'ti'], ['ot', 'e', 'vde', 'tatitefo', 'o'], ['now', 'yo', 'fa', 't', 'a', 'fa', 'o', 'pot'], ['e', 'arodet', 'e', 'tat', 'e', 'tiv', 'e', 'brat', 'bi', 'ehet'], ['o', 'yite', 'i', 'i', 'bi', 'y', 'ar', 'i'], ['no', 'fi', 'toiiet', 'bu', 'e', 'fat'], ['i', 'di', 'be', 'o', 'at', 'ever', 'lit', 'er', 'ta'], ['e', 'ateta', 'i', 'tam', 'bu', 'e', 'e', 'e', 'i', 'it', 'father'], ['a', 'bak', 'i', 'be', 'not', 'a', 'bi', 'te', 'ti'], ['ete', 'eeeeeaiue', 'eoauo'], ['ei', 'not', 'aaa', 'oe', 'bo', 'yie'], ['a', 'forte', 'an', 'than', 'i', 'cav', 'bi'], ['he', 'ea', 'i', 'toa', 'o', 'yi', 'o', 'boa', 'oo'], ['ol', 't', 'i', 't', 'i', 'tatte', 'tit', 'te'], ['but', 'never', 'ticuri', 'toatic', 'ta'], ['aeo'], ['eo', 'a'], ['lik', 'te', 'lo', 't', 'i', 'wo', 'i', 'e', 'iat'], ['i', 'ik', 'a', 'no', 'ta', 'of', 'lotic'], ['efote', 'at', 'oatte', 'a', 'ai', 'ti', 'oo'], ['an', 'i', 'iefec', 'a', 'telec', 'i', 'ut'], ['to', 'it', 'i', 'dit', 'i', 'tit', 'i'], ['foly', 'li', 'tit', 'te', 'it', 'it', 'it', 'i'], ['ietoelaoe', 'ea'], ['co', 'e', 'taee', 'eeete', 'ot', 'mo', 'vode'], ['o', 'wi', 'te', 'ta', 'ot', 'a', 'ottat', 'at', 'a', 'at', 'ate', 'fot', 'o'], ['tei', 'aeo', 'tea', 'a', 'eio'], ['i', 'late', 'mai', 'no', 'esa'], ['o', 'i', 'dot', 'we', 'otei', 'i', 'bret'], ['a', 'la', 'eo', 'e', 'ae', 'i', 'lit', 'e'], ['toit', 'noa', 'everatay'], [], ['lotei', 't'], ['and', 'o', 'i', 'io', 'ye', 'eof', 'tat'], ['lot', 'tea', 'te', 'teeea', 'teo', 'ae', 'tateo'], ['no', 'deak', 'i', 'tot', 'telot', 'o', 'tioo'], ['iti', 'not', 'ta', 'eo'], ['great', 'fa', 'efie', 'by', 'o', 'detet'], ['not', 'i', 'gan', 'catte', 'litit', 'mane'], ['la', 'tenot', 'a', 'ei', 'fo', 't', 'ite', 'e', 'e', 'ot', 'o', 'fo', 'te', 'vi'], ['an', 'havy', 'li', 'te', 'cote', 'o', 'av'], ['thak', 'e', 'e', 'car', 'childcit'], ['ut', 'yeo', 'ie'], ['you', 'tot', 'et', 'bi', 'i', 'i', 'bit', 'it', 'o'], ['no', 'e', 'e', 'blit', 'lt', 'a', 'lit', 'ee', 'li', 'otit'], ['be', 'i', 'di', 'tirte', 'tit', 'that', 'tot', 'tit'], ['i', 'i', 'ti', 'git', 'tow'], ['tit', 'delved', 'tilivee'], ['no', 'thank', 'i', 'am', 'rite', 'ity'], ['i', 'will', 'tell', 'you', 'teti', 'tri'], ['wit', 'te', 'go', 'goe', 'bot', 'got', 'te', 'e'], ['e', 'iferae', 'eta', 'iae'], ['o', 'i', 'erete'], ['leter', 'tat', 'i', 'i', 'at'], ['e', 'teeo', 'teia', 'ae', 'a', 'alla', 'oo'], ['now', 'to', 'bed', 'boy'], ['yolatand', 'i', 'to', 'my', 'folt', 'orta'], ['ifmicit', 'by', 'aro', 'i', 'i', 'i', 'i'], ['yet', 'you', 'wil', 'ep', 'p', 'ap', 'tip', 'o', 'boi', 'it', 'o'], ['e', 'a', 'ot', 'at', 'oe', 'i', 'oeee'], ['at', 'e', 'e', 'te', 'bot', 'the', 'for', 'th', 'ti', 'etat'], ['you', 'cal', 'not', 'tegete', 't', 'wi', 'te', 'ti', 'dout', 'or', 'o', 'e'], ['re', 'i', 'i', 'dio', 'o'], ['the', 'alli', 'cat', 'to', 'e', 'e', 'a', 'te', 'e', 'ot', 'o', 'a'], ['at', 'last', 'iibi', 'oi'], ['nate', 'tate', 'i', 'it', 'rage', 'o', 'aa', 'to', 'a'], ['thela', 'ie', ...

# %%
# snr = 0
print(asr_snr(0))
# Out:
# [['angor', 'an', 'pa', 'go', 'to', 'beer'], ['heaven', 'a', 'god', 'plate', 'to', 'be', 'rate', 'to'], ['head', 'a', 'ten'], ['herebity', 'recards', 'of', 'allaur', 'tot'], ['ho', 'natyou', 'o', 'weckon', 'te', 'wall'], ["i'v", 'ben', 'the', 'next', 'think', 'your', 'wife'], ['athy', 'woman', 'and', 'bon', 'i'], ['tied', 'yoar', 'woman'], ['hypocrit', 'apot', 'dever'], ['i', 'b'], ['the', 'storys', 'witten'], ['the', 'addors', 'resented', 'pustonme', 'but', 'it', 'was', 'just', 'as', 'wit', 'with', 'the', 'charms', 'me'], ['he', 'hung', 'fir', 'again', 'a', 'woman'], ['he', 'gets', 'then', 'dead', 'e', 'twenty', 'yyears'], ['she', 'sent', 'me', 'thepageis', 'anquestion', 'before', 'she', 'died'], ['so', 'simply', 'that', 'you', 'said', 'so', 'athat', 'i', 'knew', "she'd", 'havin', 'i', 'wasure'], ['you', 'a'], ['he', 'quitted', 'the', 'fire', 'and', 'dropped', 'back', 'into', 'his', 'chair'], ['probably', 'not', 'tor', 'the', 'feckan', 'i'], ['it', 'was', 'al', 'my', 'petuntot', 'everybody', 'wit', 'day'], ['cried', 'the', 'ladyyou', 'departure', 'or', 'on', 'te'], ['missus', 'gripkan', 'however', 'expesss', 'any', 'furthe', 'mor', 'like'], ['wody', 'yo', 'tall', 'daglo'], ['i', "don't", 'am', 'pitety'], ['yes', 'but', "that's", 'just', 'the', 'beauty', 'of', 'perpexon'], ['it', 'was', 'he', 'beauty', 'of', 'et'], ['but', 'with', 'that', 'o', 'rerewar', 'run', 'of', 'e', 'lad', 'tem'], ['if', 'you', 'could', 'only', 'be', 'ron', 'y', 'ber', 'ju', 'yo', 'on'], ['afbronywit', 'her', 'little', 'fate', 'wrote', 'the', 'foly', 'gon'], ['now', "yo'r", 'tay', 'di', 'tha', 'they', 'polly', 'wot', 'you'], ['there', 'there', 'de', 'bet', 'do', 'patting', 'her', 'browntue', 'had'], ['oh', 'no', 'i', 'wu', 'girl', 'by', 'barry', 'u'], ["don't", 'mind', 'it', 'pater', 'with', 'wreet', 'what', 'iv', 'hour', 'fall'], ['how', 'did', 'my', 'father', 'ever', 'meter', 'gol'], ['she', 'asked', 'e', 'pot', 'i', "didn't", 'believe', 'you', 'cuterat', 'y', 'father'], ['a', 'bath', 'ye', 'cannot', 'tat', 'ad', 'wipe', 'i', 'big', 'vigur'], ['he', 'began', 'to', 'confuse', 'wipidenc', 'witet', 'wi', 'vanish', 'wor', 'my', 'depurt', 'y', 'elo'], ['if', 'not', 'so', 'urnas', 'the', 'min', 'beep', 'momers', 'child'], ['a', 'goty', 'fortn', 'an', 'a', 'happy', 'bi'], ['wus', 'like', 'us', 'my', 'father', 'i', 'tee', 'and', 'yet', 'withdot', 'my', 'father'], ['so', 'there', 'was', 'a', 'triig', 'page', 'who', 'turned', 'it', 'toward', 'me'], ['but', 'then', 'te', 'picture', 'was', 'gon', 'as', 'quittmey', 'at', 'it', 'te'], ['site', 'nowte', 'hee', 'te', 'laater'], ['take', 'e', 'all', 'pate', 'and', 'let', 'us', 'few', 'at', 'the', 'crittitetur'], ['wiht', 'with', 'yot', 'young', 'master', 'yo', 'i', 'am', 'at', 'yo', 'te', 'man'], ['by', 'the', 'a', 'notin', 'o', 'a', 'notti', 'gi'], ['he', 'pore', 'them', 'trut', 'th', 'trover', 'an', 'thi', 'three', 'tim', 'cap', 'wit', 'a', 'terifine'], ['and', 'then', 'laby', 'came', 'deck', 'd', 'would', 'exnac', 'yor', 'pertunal'], ['o', 'i', 'did', 'pushe', 'tis', 'tel'], ['ssurely', 'we', 'can', 'comit', 'with', 'god', 'grace'], ['she', 'is', 'pit', 'ly', 'a', 'a', 'pood', 'tan', 'a', 'gor', 'te', 'lev', 'for', 'an', 'attemti'], ['come', 'to', 'me', 'then', 'her', 'here', 'he', 'baite', 'ter', 'voice', 'toa', 'louder'], ['the', 'gover', 'took', 'ter', 'partn', 'i', 'te', 'partetat', 'nowi', 'te', 'hat', 'e', 'ctan', 'e', 'leating', 'off', 'the', 'bot'], ['wit', 'wire', 'hop', 'ta', 'truk', 'them', 'allinanter', 'ti', 'tiof'], ['sylent', 'yo', 'na', 'cried', 'moncunchat'], ['he', 'felt', 'burn', 'downwer', 'with', 'is', 'back', 'bot', 'his', 'wir', 's', 'quite', 'o', 'breath'], ['o', 'wat', 'te', 'ay', 'a', 'lot', 'e', 'tay', 'ela', 'to', 'the', 'rest', 'fie'], ['george', 'monpe', 'jay', 'weur', 'never', 'get', 'ti', 'day'], ['what', 'is', 'your', 'name', 'orgin', 'askd', 'the', 'tis', 'coller', 'cose'], ['ropin', 'fifty'], ['and', 'mine', 'if', 'weol', 'fatly', 'shall', 'we', 'be', 'come', 'rat'], ['right', 'will ...

# %%
# snr = 5
print(asr_snr(5))
# Out:
# [['angor', 'pan', 'pango', 'to', 'beer'], ['heaven', 'a', 'grood', 'place', 'to', 'be', 'raised', 'to'], ['hedge', 'a', 'fence'], ['heredity', 'the', 'cause', 'of', 'all', 'our', 'falt'], ['hos', 'nat', 'excuse', 'for', 'wetking', 'te', 'walk'], ['husbeen', 'the', 'next', 'thing', 'to', 'a', 'wife'], ['hafee', 'woman', 'and', 'bon', 'tie'], ['te', 'tie', 'to', 'ar', 'woman'], ['hypocrit', 'acorse', 'dearler'], ['i', 'me'], ['the', 'story', 'is', 'written'], ['the', 'others', 'resented', 'posponient', 'but', 'it', 'was', 'just', 'a', 'scruple', 'the', 'charmed', 'me'], ['he', 'hung', 'fire', 'again', 'a', 'woman'], ['she', 'has', 'been', 'dead', 'these', 'twenty', 'years'], ['she', 'sant', 'meo', 'the', 'pages', 'in', 'questioned', 'before', 'she', 'died'], ['some', 'simply', 'that', 'she', 'said', 'so', 'that', 'i', 'knew', 'she', "hadn't", 'i', 'was', 'sure', 'i', 'could', 'see'], ['you', 'are', 'acute'], ['he', 'quitted', 'the', 'fire', 'and', 'dropped', 'back', 'into', 'his', 'chair'], ['probably', 'not', 'to', 'ave', 'affecind', 'pos'], ['it', 'was', 'almost', 'peturnd', 'apout', 'everybody', 'will', 'stay'], ['cried', 'the', 'ladies', 'whose', 'departure', 'had', 'been', 'fixed'], ['missus', 'grippin', 'however', 'expressed', 'the', 'need', 'for', 'a', 'little', 'more', 'light'], ["won't", 'you', 'tell', 'dugret'], ['i', "don't", 'anticipate'], ['yes', 'but', "that's", 'just', 'the', 'beauty', 'of', 'her', 'passion'], ['it', 'was', 'the', 'beauty', 'of', 'it'], ['wut', 'was', 'that', 'all', 'her', 'reward', 'one', 'of', 'te', 'ladis', 'ons'], ['if', 'she', 'could', 'only', 'be', 'fronzy', 'for', 'just', 'one', 'rome'], ['aftr', 'broni', 'with', 'her', 'little', 'face', 'both', 'the', "pador's", 'own'], ['now', "you'r", 'ta', 'cried', 'fan', 'tay', 'polly', "won't", 'you'], ['there', 'there', 'he', 'tet', 'tubiy', 'patting', 'her', 'brown', 'but', 'ye', 'head'], ['oh', 'no', 'docter', "i'm", 'a', 'gir', 'by', 'am', 'a', 'very', 'onf'], ["don't", 'mind', 'it', 'pally', 'whispered', 'jafper', 'what', "n't", 'her', 'fall'], ['how', 'did', 'her', 'mother', 'ever', 'meker', 'go'], ['she', 'asked', 'dimple', 'i', "didn't", 'believe', 'you', 'could', 'persuade', 'myr', 'father'], ['at', 'las', 'he', 'came', 'out', 'at', 'them', 'and', 'wiped', 'hi', 'they', 'pigirosthem'], ['he', 'began', 'a', 'confused', 'complaint', 'against', 'he', 'wizard', 'who', 'had', 'vanished', 'behind', 'the', 'curtain', 'on', 'the', 'left'], ['is', 'not', 'so', 'earnest', 'a', 'mined', 'to', 'be', 'memoryos', 'child'], ['a', 'golden', 'fortune', 'in', 'a', 'happy', 'life'], ['he', 'wous', 'like', 'up', 'to', 'my', 'father', 'i', 'the', 'way', 'and', 'yet', 'with', 'not', 'my', 'father'], ['also', 'there', 'was', 'a', 'strippling', 'page', 'who', 'turned', 'it', 'to', 'a', 'mad'], ['ut', 'then', 'the', 'picture', 'was', 'gone', 'as', 'quickly', 'as', 'the', 'king'], ['sister', 'ne', 'do', 'you', 'hear', 'these', 'marvels'], ['take', 'your', 'place', 'arnd', 'let', 'us', 'see', 'ou', 'what', 'the', 'cristal', 'can', 'show', 'to', 'you'], ['like', 'is', 'not', 'young', 'master', 'though', 'i', 'am', 'an', 'old', 'man'], ['crids', 'of', 'a', 'nottingham', 'a', 'notting', 'ham'], ['before', 'them', 'thread', 'the', 'strover', 'and', 'his', 'three', 'sons', 'caplas', 'of', 'terrifin'], ['and', 'then', 'they', 'became', 'vexed', 'and', 'would', 'have', 'snatched', 'your', 'perse', 'from', 'us'], ['so', 'i', 'did', 'push', 'this', 'fellow'], ['surely', 'we', 'can', 'submit', 'with', 'good', 'grace'], ['tis', 'fight', 'rebuda', 'talkold', 'man', 'answered', 'the', 'weden', 'so', 'in', 'a', 'prantice'], ['come', 'to', 'me', 'men', 'her', 'her', 'he', 'raised', 'hir', 'voice', 'froma', 'louder'], ['the', 'strovers', 'took', 'their', 'partn', 'ant', 'thi', 'party', 'zet', 'now', 'that', 'they', 'had', 'to', 'chance', 'of', 'beating', 'off', 'their', 'fos'], ['this', 'wire', 'helped', 'to', 'thrust', 'them', 'all', 'in', 'and', 'entered', 'swiftly', 'himself'], ['s ...

# %%
# snr = 10
print(asr_snr(10))
# Out:
# [['angor', 'pane', 'painful', 'to', 'hear'], ['heaven', 'a', 'good', 'place', 'to', 'be', 'raised', 'too'], ['hedge', 'a', 'fence'], ['heredity', 'the', 'cause', 'of', 'all', 'our', 'faults'], ['hers', "man's", 'excuse', 'for', 'wetting', 'the', 'walk'], ['husband', 'the', 'next', 'thing', 'to', 'a', 'wife'], ['hussy', 'woman', 'and', 'ban', 'tie'], ['tied', 'to', 'a', 'woman'], ['hypocrit', 'a', 'horse', 'dearler'], ['i', 'b'], ['the', 'story', 'is', 'written'], ['the', 'others', 'resented', 'posponment', 'but', 'it', 'was', 'justie', 'scruple', 'that', 'charmed', 'me'], ['he', 'hung', 'pire', 'again', 'a', "woman's"], ['she', 'has', 'been', 'dead', 'these', 'twenty', 'years'], ['she', 'sent', 'me', 'the', 'pages', 'in', 'questioned', 'before', 'she', 'died'], ['was', 'on', 'simply', 'that', 'she', 'said', 'so', 'ut', 'that', 'i', 'knew', 'she', "hadn't", 'i', 'was', 'sure', 'i', 'could', 'see'], ['you', 'are', 'accute'], ['he', 'quitted', 'the', 'fire', 'and', 'dropped', 'back', 'into', 'his', 'chair'], ['probably', 'not', 'to', 'the', 'second', 'post'], ['it', 'was', 'almost', 'petone', 'of', 'hope', 'everybody', 'will', 'stay'], ['cried', 'the', 'ladies', 'whose', 'departure', 'hade', 'been', 'fixed'], ['missus', 'griffin', 'however', 'expressed', 'the', 'need', 'for', 'a', 'little', 'more', 'light'], ["won't", 'you', 'tell', 'douglis'], ['i', "don't", 'anticipate'], ['yes', 'but', "that's", 'just', 'the', 'beauty', 'of', 'her', 'passion'], ['it', 'was', 'the', 'beauty', 'of', 'it'], ['but', 'was', 'that', 'all', 'her', 'reward', 'one', 'of', 'the', 'ladies', 'a'], ['if', 'she', 'could', 'only', 'be', 'pronsi', 'for', 'just', 'one', 'moment'], ['asked', 'bronzi', 'with', 'her', 'little', 'face', 'close', 'to', "polly's", 'own'], ['now', "yo'll", 'tay', 'cried', 'van', 'tay', 'polly', "won't", 'you'], ['there', 'there', 'he', 'said', 'tootingly', 'patting', 'her', 'brown', 'fuzzy', 'head'], ['oh', 'no', 'japter', "i'm", 'a', 'girl', 'by', 'my', 'very', 'on', 'tout'], ["don't", 'mind', 'it', 'polly', 'whispered', 'jasper', "wasn't", 'her', 'fault'], ['how', 'did', 'her', 'mother', 'ever', 'let', 'her', 'go'], ['she', 'asked', 'importently', 'i', "didn't", 'believe', 'you', 'could', 'persuade', 'her', 'father'], ['at', 'last', 'he', 'came', 'out', 'of', 'them', 'and', 'wiped', 'his', 'faith', 'vigorously'], ['he', 'began', 'a', 'confused', 'complaint', 'against', 'the', 'wizard', 'who', 'had', 'vanished', 'behind', 'the', 'curtain', 'on', 'the', 'left'], ['giv', 'not', 'so', 'earnest', 'a', 'mind', 'to', 'be', 'is', 'memoris', 'child'], ['a', 'golden', 'fortune', 'in', 'a', 'happy', 'life'], ['he', 'was', 'likeu', 'to', 'my', 'father', 'in', 'a', 'way', 'and', 'yet', 'was', 'not', 'my', 'father'], ['also', 'there', 'was', 'a', 'strippling', 'page', 'who', 'turned', 'it', 'to', 'a', 'maid'], ['but', 'then', 'the', 'picture', 'was', 'gone', 'as', 'quickly', 'as', 'it', 'came'], ['sister', 'ne', 'do', 'you', 'hear', 'these', 'marbles'], ['take', 'your', 'place', 'and', 'let', 'us', 'see', 'what', 'the', 'cristal', 'can', 'show', 'to', 'you'], ['like', 'is', 'not', 'young', 'master', 'though', 'i', 'am', 'an', 'old', 'man'], ['cries', 'of', 'a', 'nottingham', 'a', 'notting', 'ham'], ['before', 'them', 'tled', 'the', 'stroller', 'and', 'his', 'three', 'sons', 'capitlas', 'and', 'terrified'], ['and', 'then', 'they', 'became', 'vexed', 'and', 'would', 'have', 'snatched', 'your', 'purse', 'from', 'us'], ['so', 'i', 'did', 'push', 'this', 'fellow'], ['surely', 'we', 'can', 'submit', 'with', 'good', 'grace'], ['tis', 'find', 'for', 'you', 'to', 'talk', 'old', 'man', 'answered', 'the', 'lean', 'so', 'in', 'a', 'prentice'], ['come', 'to', 'me', 'men', 'her', 'her', 'he', 'raised', 'his', 'voice', 'still', 'louder'], ['the', 'strollers', 'took', 'their', 'part', 'in', 'it', 'with', 'hardyzess', 'now', 'that', 'they', 'had', 'some', 'chance', 'of', 'beating', 'off', 'their', 'bows'], ['the', 'squire', 'helped', 'to', 'thrust', 'them', 'all ...

# %% [markdown]
# ## Influence of the amount of training data
#
# So far, we have used a model that was fine-tuned for ASR on 100 hours of speech, but alternative models exist in torchaudio (recall the list of pipelines is [here](https://pytorch.org/audio/stable/pipelines.html#id36)).
#
# <span style="color:red"> **Exercise 4**</span>. Perform ASR on the dataset and compute the WER for models that are fine-tuned with either less or more speech data, and comment. Be careful of using models using the same architecture (basic wav2vec2) for a fair comparison.

# %% [markdown]
# Finally, note that many other pretrained models are readily available in torchaudio, such as a:
# - larger models (e.g., `'WAV2VEC2_ASR_LARGE_10M'`)
# - model trained using another dataset (e.g., `'WAV2VEC2_ASR_LARGE_LV60K_10M'`)
# - alternative architectures (e.g., `'HUBERT_ASR_LARGE'`).
#
# Feel free to experiment with these!
